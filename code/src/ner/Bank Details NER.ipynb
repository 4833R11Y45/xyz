# %%
import os
import random
import string

import spacy
from spacy.training import Example

# %%
MODEL_DIR = "../../bank_dets_model"
if not os.path.isdir(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
ENTITIES = [
        "InvoiceNum",
        "PO",
        "InvoiceDate",
        "DueDate",
        "ABN"
    ]

BANK_DETAILS_ENTITIES = ["ABN", "AccountName", "AccountNum", "BankName", "BSB", "SwiftCode"]

# %%
def create_test_train_split(folder):

    files = os.listdir(folder)
    # files = [os.path.join(folder, fil) for fil in files]
    files = sorted(list(set([fil[:-4] for fil in files])))
    random.shuffle(files)

    train_folder = os.path.join(folder, "train")
    test_folder = os.path.join(folder, "test")
    if not os.path.isdir(train_folder):
        os.mkdir(train_folder)
    if not os.path.isdir(test_folder):
        os.mkdir(test_folder)

    split_point = int(len(files)*0.8)
    print("Training files: ", split_point)
    train_files = files[:split_point]
    test_files = files[split_point:]

    for fil in files:
        if fil in train_files:
            os.rename(os.path.join(folder, fil+".txt"), os.path.join(train_folder, fil+".txt"))
            os.rename(os.path.join(folder, fil+".ann"), os.path.join(train_folder, fil+".ann"))
        else:
            os.rename(os.path.join(folder, fil+".txt"), os.path.join(test_folder, fil+".txt"))
            os.rename(os.path.join(folder, fil+".ann"), os.path.join(test_folder, fil+".ann"))

# %%
def prepare_train_data(folder):
    files1 = os.listdir(folder)
    # files = [tf for tf in files if tf!="annotation.conf"]
    files1 = list(set([tf[:-4] for tf in files1]))

    data = []
    for tf in sorted(files1):
        print(tf)
        entities_dict = {"entities": []}
        try:
            with open(os.path.join(folder, tf+".txt"), "r") as f:
                text = f.read()
        except UnicodeDecodeError as e:
            with open(os.path.join(folder, tf+".txt"), "r", encoding="mbcs") as f:
                text = f.read()
#         print("Text: ", text)
        with open(os.path.join(folder, tf+".ann"), "r") as f:
            annotation = f.readlines()
        for line in annotation:
            print("Line: ", line)
            line_parts = line.split("\t")
            if len(line_parts) == 3:
                relevant_bit = line_parts[1]
                entity_text = line_parts[2]
                entity_text = entity_text.strip()
                ent, start, end = relevant_bit.split(" ")
                start = text.find(entity_text)
                end = start + len(entity_text)
                print(start, end, ent)
                entities_dict["entities"].append((int(start), int(end), ent))
        entities_dict["entities"] = list(set(entities_dict["entities"]))
        data.append((text, entities_dict))
    random.shuffle(data)
#     data = trim_entity_spans(data)
    return data

# %%
def train(train_data, num_epochs=25):
    model_name = "ner_model"
    nlp = spacy.load("en_core_web_sm")

    # Getting the ner component
    ner = nlp.get_pipe('ner')

    for ent in BANK_DETAILS_ENTITIES:
        ner.add_label(ent)

    # Resume training
    optimizer = nlp.resume_training()
    move_names = list(ner.move_names)

    # List of pipes you want to train
    pipe_exceptions = ["ner"]

    # List of pipes which should remain unaffected in training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

    with nlp.disable_pipes(*other_pipes):
        for itn in range(num_epochs):
            for batch in spacy.util.minibatch(train_data, size=8):
                for text, annotations in batch:
                    #             print(text[:10])
                    #             print(annotations)
                    losses = {}
                    # create Example
                    translator = str.maketrans(string.punctuation, ' ' * len(string.punctuation))
                    text = text.translate(translator)
                    doc = nlp.make_doc(text)
#                     print(type(doc))
#                     print(type(annotations))
#                     print("Annot: ", annotations)
#                     dlks
                    example = Example.from_dict(doc, annotations)
                    #             print(example)
                    # Update the model
                    nlp.update([example], losses=losses, drop=0.3)
                    print("Losses", losses)

    nlp.to_disk(os.path.join(MODEL_DIR, model_name))
    return nlp

# %%
TRAIN_DATA = prepare_train_data("../../data/train")
TEST_DATA = prepare_train_data("../../data/test")
# Out:
# 00028104
# Line:  T1	BSB 1387 1394	062-198
#
# 1279 1286 BSB
# Line:  T2	AccountNum 1409 1418	1058-3208
#
# 1301 1310 AccountNum
# Line:  T3	AccountName 1433 1458	About Face Salon Supplies
#
# 64 89 AccountName
# Line:  T4	ABN 52 66	16 123 351 422
#
# 48 62 ABN
# 02081934
# Line:  T1	BSB 1189 1196	064 173
#
# 1100 1107 BSB
# Line:  T2	AccountNum 1207 1216	0012 5328
#
# 1118 1127 AccountNum
# Line:  T3	SwiftCode 1230 1238	CTBAAU2S
#
# 1141 1149 SwiftCode
# Line:  T4	AccountName 2084 2098	Data#3 Limited
#
# 1009 1023 AccountName
# Line:  T5	BSB 2115 2122	064 173
#
# 1100 1107 BSB
# Line:  T6	AccountNum 2133 2142	0012 5328
#
# 1118 1127 AccountNum
# Line:  T7	SwiftCode 2156 2164	CTBAAU2S
#
# 1141 1149 SwiftCode
# Line:  T8	ABN 1438 1452	31 010 545 267
#
# 1344 1358 ABN
# 082172_Adjustment Credit Note_CCE04694 (ID 5951179)
# Line:  T1	ABN 77 91	63 000 341 819
#
# 74 88 ABN
# Line:  T2	AccountNum 3480 3489	775394025
#
# 3365 3374 AccountNum
# Line:  T3	BSB 3378 3385	014-002
#
# 3266 3273 BSB
# 082172_Tax Invoice_CIY76735 (ID 5952822)
# Line:  T1	ABN 77 91	63 000 341 819
#
# 74 88 ABN
# Line:  T2	BSB 3528 3535	014-002
#
# 3405 3412 BSB
# Line:  T3	AccountNum 3630 3639	775394025
#
# 3504 3513 AccountNum
# 1000_2800013874_2022
# Line:  T1	ABN 212 223	11259448410
#
# 192 203 ABN
# Line:  T2	BSB 466 473	033-157
#
# 433 440 BSB
# Line:  T3	AccountNum 498 507	000183918
#
# 463 472 AccountNum
# 11481089
# Line:  T1	ABN 140 154	46 076 468 481
#
# 127 141 ABN
# 12082021155120-0001
# Line:  T1	ABN 271 285	64 058 914 668
#
# 258 272 ABN
# Line:  T2	AccountName 1339 1383	Thomson Reuters (Professional) Australia Ltd
#
# 1243 1287 AccountName
# Line:  T3	AccountNum 1260 1266	276484
#
# 1170 1176 AccountNum
# Line:  T4	BSB 1186 1193	032-000
#
# 1100 1107 BSB
# 16.11.21+-+Prezzee_Invoice_AU188F69DE_yopzm
# Line:  T1	ABN 783 794	16602963422
#
# 743 754 ABN
# Line:  T2	AccountName 129 144	Prezzee Pty Ltd
#
# 121 136 AccountName
# Line:  T3	BSB 176 182	082187
#
# 166 172 BSB
# Line:  T4	AccountNum 212 221	665435922
#
# 200 209 AccountNum
# 2022281
# Line:  T1	ABN 407 421	77 076 347 914
#
# 382 396 ABN
# Line:  T2	BankName 646 663	Bank of Melbourne
#
# 609 626 BankName
# Line:  T3	AccountName 682 704	ORIMA Research Pty Ltd
#
# 643 665 AccountName
# Line:  T4	BSB 727 734	193-879
#
# 686 693 BSB
# Line:  T5	AccountNum 741 752	479 409 835
#
# 699 710 AccountNum
# 4307814375
# Line:  T1	ABN 1023 1037	48 002 487 096
#
# 951 965 ABN
# Line:  T2	BankName 1146 1158	HSBC Limited
#
# 1071 1083 BankName
# Line:  T3	BSB 1164 1171	343 001
#
# 1089 1096 BSB
# Line:  T4	AccountNum 1181 1191	223072 001
#
# 1106 1116 AccountNum
# 46730
# Line:  T1	BSB 581 588	012-318
#
# 539 546 BSB
# Line:  T2	AccountNum 616 625	230375991
#
# 571 580 AccountNum
# Line:  T3	SwiftCode 656 664	ANZBAU3M
#
# 608 616 SwiftCode
# Line:  T4	ABN 817 831	57 003 299 572
#
# 761 775 ABN
# 55448
# Line:  T1	ABN 24 38	63 547 547 828
#
# 23 37 ABN
# Line:  T2	ABN 214 228	63 547 547 828
#
# 23 37 ABN
# Line:  T3	BSB 645 651	032510
#
# 601 607 BSB
# Line:  T4	AccountNum 661 667	991496
#
# 617 623 AccountNum
# 90914614
# Line:  T1	ABN 172 186	65 003 371 239
#
# 163 177 ABN
# Line:  T2	AccountName 1172 1190	NTT Australia P/L,
#
# 1114 1132 AccountName
# Line:  T3	BSB 1196 1203	012-201
#
# 1138 1145 BSB
# Line:  T4	AccountNum 1211 1220	837120709
#
# 1153 1162 AccountNum
# AR Invoice_10000979 IP Australia_IN0012334 - Ops _ Nuance
# Line:  T1	ABN 118 132	94 624 615 925
#
# 111 125 ABN
# Line:  T2	BSB 1138 1145	083-004
#
# 1049 1056 BSB
# Line:  T3	AccountNum 1160 1169	237072651
#
# 1069 1078 AccountNum
# Line:  T4	SwiftCode 1182 1193	NATAAU3303M
#
# 1089 1100 SwiftCode
# Line:  T5	BankName 1207 1210	NAB
#
# 1112 1115 BankName
# Line:  T6	AccountName 1227 1251	Probe Operations Pty Ltd
#
# 68 92 AccountName
# C08346_01-Feb-2022
# Line:  T1	ABN 1005 1019	11 002 533 851
#
# 942 956 ABN
# Line:  T2	BSB 887 894	062-000
#
# 829 836 BSB
# Line:  T3	AccountNum 912 920	10657117
#
# 853 861 AccountNum
# Line:  T5	SwiftCode 854 862	CTBAAU2S
#
# 799 807 SwiftCode
# Line:  T4	AccountName 826 845	Isentia Pty Limited
#
# 772 791 AccountName
# Line:  T6	BankName 754 784	Commonwealth Bank of Australia
#
# 702 732 BankName
# Line:  T7	ABN 2211 2225	11 002 533 851
#
# 942 956 ABN
# Line:  T8	AccountNum 2118 2126	10657117
#
# 853 861 AccountNum
# Line:  T9	SwiftCode 2060 2068	CTBAAU2S
#
# 799 807 SwiftCode
# Line:  T10	AccountName 2032 2051	Isentia Pty Limited
#
# 772 791 AccountName
# Line:  T11	BSB 2093 2100	062-000
#
# 829 836 BSB
# Line:  T12	BankName 1960 1990	Commonwealth Bank of Australia
#
# 702 732 BankName
# Clarivate API Renewal Invoice April 2021
# Line:  T1	SwiftCode 1973 1981	CITIGB2L
#
# 1862 1870 SwiftCode
# Line:  T2	AccountNum 1953 1961	12705621
#
# 1843 1851 AccountNum
# Line:  T3	BSB 1936 1944	18-50-08
#
# 1826 1834 BSB
# INV-70232
# Line:  T1	ABN 173 187	14 412 355 131
#
# 163 177 ABN
# Line:  T2	AccountName 888 899	Abe's Audio
#
# 0 11 AccountName
# Line:  T3	BSB 926 933	017 526
#
# 870 877 BSB
# Line:  T4	AccountNum 980 989	642816271
#
# 922 931 AccountNum
# INV-8901
# Line:  T1	ABN 389 403	93 272 836 959
#
# 367 381 ABN
# Line:  T2	AccountNum 675 684	393068435
#
# 634 643 AccountNum
# Line:  T3	BSB 662 668	012510
#
# 622 628 BSB
# INV00001497
# Line:  T1	BSB 1039 1046	083-004
#
# 997 1004 BSB
# Line:  T2	SwiftCode 1086 1096	NATAA3303M
#
# 1043 1053 SwiftCode
# Line:  T3	AccountNum 1064 1074	46608 2335
#
# 1021 1031 AccountNum
# Line:  T4	AccountName 1008 1032	Words and Beyond Pty Ltd
#
# 757 781 AccountName
# Line:  T5	ABN 158 172	29 086 468 233
#
# 154 168 ABN
# INV2171274
# Line:  T1	ABN 150 164	16 600 428 537
#
# 144 158 ABN
# Line:  T2	AccountName 292 324	Andrews M eat Industries Pty Ltd
#
# 279 311 AccountName
# Line:  T3	AccountNum 367 375	11362868
#
# 351 359 AccountNum
# Line:  T4	BSB 348 355	062-184
#
# 332 339 BSB
# INVOICE_162_Hired_Thought
# Line:  T1	SwiftCode 574 582	SMBUUS41
#
# 534 542 SwiftCode
# Line:  T2	AccountNum 617 627	1010306103
#
# 575 585 AccountNum
# IP Australia - Internal Audit Bill (January 2022)
# Line:  T1	ABN 69 83	20 607 773 295
#
# 66 80 ABN
# Line:  T2	BSB 1455 1461	012006
#
# 1383 1389 BSB
# Line:  T3	BankName 1342 1359	ANZ Banking Group
#
# 1278 1295 BankName
# Line:  T4	AccountNum 1481 1490	836800972
#
# 1406 1415 AccountNum
# Line:  T5	SwiftCode 1543 1551	ANZBAU3M
#
# 1466 1474 SwiftCode
# Line:  T6	AccountName 1202 1224	PricewaterhouseCoopers
#
# 4 26 AccountName
# IPA HM-12299-EIP -1800007311
# Line:  T1	ABN 59 73	96 257 979 159
#
# 56 70 ABN
# Line:  T2	BSB 1259 1265	092009
#
# 1208 1214 BSB
# Line:  T3	AccountNum 1274 1280	122020
#
# 1223 1229 AccountNum
# IPBAU Q2 21-22 invoice
# Line:  T1	ABN 186 200	74 599 608 295
#
# 178 192 ABN
# Line:  T2	BankName 871 896	Reserve Bank of Australia
#
# 824 849 BankName
# Line:  T3	AccountName 1060 1103	Department of Industry, Science, Energy and Resources
#
# 1080 1133 AccountName
# Line:  T4	AccountNum 1256 1262	118689
#
# 1194 1200 AccountNum
# Line:  T5	SwiftCode 1284 1292	RSBKAU2S
#
# 1219 1227 SwiftCode
# Line:  T6	BSB 1201 1208	092-009
#
# 1142 1149 BSB
# Line:  T7	ABN 1824 1838	74 599 608 295
#
# 178 192 ABN
# Invoice 000015800
# Line:  T1	ABN 71 85	33 129 377 180
#
# 66 80 ABN
# Line:  T2	SwiftCode 1118 1126	CTBAAU2S
#
# 1042 1050 SwiftCode
# Line:  T3	AccountNum 1099 1108	1065 3883
#
# 1025 1034 AccountNum
# Line:  T4	BSB 1081 1088	062 009
#
# 1009 1016 BSB
# Line:  T5	AccountName 1058 1073	Servian Pty Ltd
#
# 34 49 AccountName
# Line:  T6	ABN 1192 1206	33 129 377 180
#
# 66 80 ABN
# Invoice 110-31
# Line:  T1	ABN 261 275	62 132 569 941
#
# 240 254 ABN
# Line:  T2	AccountNum 686 697	410 503 006
#
# 642 653 AccountNum
# Line:  T3	BSB 661 668	112-908
#
# 618 625 BSB
# Line:  T4	AccountName 640 654	Ionize Pty Ltd
#
# 32 46 AccountName
# Invoice 25979
# Line:  T1	ABN 198 212	38 113 072 755
#
# 186 200 ABN
# Line:  T2	BSB 767 774	063 000
#
# 726 733 BSB
# Line:  T3	AccountNum 785 794	1021 9772
#
# 743 752 AccountNum
# Line:  T4	AccountName 732 759	Chin Communications Pty Ltd
#
# 693 720 AccountName
# Invoice 32324
# Line:  T1	ABN 250 264	38 113 072 755
#
# 232 246 ABN
# Line:  T2	AccountName 728 749	GoLogic Group Pty Ltd
#
# 34 55 AccountName
# Line:  T3	BankName 762 765	ANZ
#
# 715 718 BankName
# Line:  T4	BSB 772 779	014-734
#
# 724 731 BSB
# Line:  T5	AccountNum 792 801	1979 7014
#
# 743 752 AccountNum
# Line:  T6	SwiftCode 811 819	ANZBAU3M
#
# 761 769 SwiftCode
# Invoice 8328
# Line:  T1	AccountNum 850 858	10629470
#
# 812 820 AccountNum
# Line:  T2	PO 825 832	062-099
#
# 788 795 PO
# Line:  T3	AccountName 866 891	Stirling Andersen Pty Ltd
#
# 665 690 AccountName
# Line:  T4	ABN 1274 1288	58 137 109 525
#
# 1223 1237 ABN
# Invoice INV-02237
# Line:  T1	ABN 375 389	72 133 413 920
#
# 352 366 ABN
# Line:  T2	SwiftCode 1541 1553	NATAAU 3303M
#
# 1446 1458 SwiftCode
# Line:  T3	BSB 1520 1527	086 131
#
# 1426 1433 BSB
# Line:  T4	AccountNum 1502 1513	726 557 641
#
# 1409 1420 AccountNum
# Line:  T5	AccountName 1455 1484	Kondinin Information Services
#
# 1363 1392 AccountName
# Line:  T6	BankName 1416 1438	National Australia Ban
#
# 1325 1347 BankName
# Invoice INV-0489 - IP Australia GM PEG B1
# Line:  T1	ABN 81 95	88 088 137 071
#
# 75 89 ABN
# Line:  T2	AccountNum 958 969	825-017-456
#
# 905 916 AccountNum
# Line:  T3	BSB 932 939	082-902
#
# 881 888 BSB
# Line:  T4	BankName 901 924	National Australia Bank
#
# 852 875 BankName
# Line:  T5	AccountName 856 892	Executive Intelligence Group Pty Ltd
#
# 809 845 AccountName
# Invoice INV-1192318
# Line:  T1	ABN 172 183	38113072755
#
# 161 172 ABN
# Line:  T2	ABN 360 374	87 166 205 287
#
# 337 351 ABN
# Line:  T3	BSB 733 739	124010
#
# 688 694 BSB
# Line:  T4	AccountNum 746 755	022451345
#
# 700 709 AccountNum
# Line:  T5	AccountName 711 726	Thesoco Pty Ltd
#
# 31 46 AccountName
# Invoice INV-4600
# Line:  T1	ABN 690 704	61 610 143 863
#
# 255 269 ABN
# Line:  T2	AccountName 628 648	MTP Services Pty Ltd
#
# 39 59 AccountName
# Line:  T3	AccountNum 605 616	90-751-8182
#
# 566 577 AccountNum
# Line:  T4	BSB 584 591	082-902
#
# 546 553 BSB
# Line:  T5	ABN 274 288	61 610 143 863
#
# 255 269 ABN
# Invoice PSINV009249
# Line:  T1	ABN 206 220	67 111 307 361
#
# 190 204 ABN
# Line:  T2	AccountNum 919 927	15073065
#
# 856 864 AccountNum
# Line:  T3	BankName 897 900	CBA
#
# 836 839 BankName
# Line:  T4	BSB 935 942	062-000
#
# 870 877 BSB
# Invoice Sightline-8138
# Line:  T1	ABN 91 105	86 143 688 546
#
# 86 100 ABN
# Line:  T2	BankName 988 1005	Commonwealth Bank
#
# 938 955 BankName
# Line:  T3	BSB 1012 1019	062-192
#
# 961 968 BSB
# Line:  T4	AccountNum 1027 1036	1044 0166
#
# 975 984 AccountNum
# Line:  T5	SwiftCode 1050 1058	CTBAAU2S
#
# 997 1005 SwiftCode
# Line:  T6	ABN 1112 1126	86 143 688 546
#
# 86 100 ABN
# Invoice-20220202164109-000102
# Line:  T1	ABN 1089 1103	32 094 147 403
#
# 51 65 ABN
# Line:  T2	ABN 54 68	32 094 147 403
#
# 51 65 ABN
# Line:  T3	AccountNum 860 869	478000003
#
# 808 817 AccountNum
# Line:  T4	BSB 842 849	083 032
#
# 790 797 BSB
# Invoice_AU251554874
# Line:  T1	AccountNum 1770 1779	464934397
#
# 1702 1711 AccountNum
# Line:  T2	BSB 1749 1756	082-926
#
# 1683 1690 BSB
# Line:  T3	ABN 1842 1856	32 086 209 403
#
# 773 787 ABN
# Line:  T4	AccountName 1623 1649	Web Active Corporation Pty
#
# 736 762 AccountName
# Line:  T5	ABN 798 812	32 086 209 403
#
# 773 787 ABN
# M515740
# Line:  T1	AccountNum 925 935	C000378487
#
# 875 885 AccountNum
# Line:  T2	ABN 288 302	89 755 348 137
#
# 276 290 ABN
# Line:  T3	AccountNum 1239 1247	20158181
#
# 1183 1191 AccountNum
# Line:  T4	AccountNum 1351 1369	NL48INGB0020158181
#
# 1294 1312 AccountNum
# Line:  T5	SwiftCode 1327 1335	INGBNL2A
#
# 1270 1278 SwiftCode
# Moby Dick Boat est
# Line:  T1	ABN 203 217	89 604 591 077
#
# 189 203 ABN
# Line:  T2	SwiftCode 1318 1326	CTBAAU2S
#
# 1271 1279 SwiftCode
# Line:  T3	AccountNum 1295 1304	1062 9913
#
# 1249 1258 AccountNum
# Line:  T4	BSB 1280 1287	06 2021
#
# 1235 1242 BSB
# Line:  T5	AccountName 1248 1273	Moby Dick Content Pty Ltd
#
# 1204 1229 AccountName
# NEXTDC Limited_INV0000054251
# Line:  T1	BSB 1739 1746	084-004
#
# 1635 1642 BSB
# Line:  T2	AccountNum 1765 1774	837407013
#
# 1661 1670 AccountNum
# Line:  T3	BankName 1729 1732	NAB
#
# 1626 1629 BankName
# Line:  T4	AccountName 1811 1825	NEXTDC LIMITED
#
# 1704 1718 AccountName
# Line:  T5	ABN 2132 2146	35 143 582 521
#
# 2012 2026 ABN
# NRMA Westfield Liverpool 2019 Outgoings Wash Up
# Line:  T1	ABN 231 245	55 000 712 710
#
# 223 237 ABN
# Line:  T2	AccountNum 3007 3015	10533700
#
# 2861 2869 AccountNum
# Line:  T3	BSB 2942 2949	062-021
#
# 2824 2831 BSB
# Line:  T4	BSB 2957 2964	062-021
#
# 2824 2831 BSB
# Line:  T5	AccountNum 2984 2992	10533700
#
# 2861 2869 AccountNum
# Line:  T6	ABN 3582 3596	69 079 137 518
#
# 3437 3451 ABN
# SSIN-112247
# Line:  T1	ABN 59 73	48 003 491 496
#
# 54 68 ABN
# Line:  T2	BSB 1402 1409	032 134
#
# 1298 1305 BSB
# Line:  T3	AccountNum 1419 1426	127 169
#
# 1315 1322 AccountNum
# Line:  T4	AccountName 1427 1451	ZEREX P/L WESTPAC SYDNEY
#
# 1323 1347 AccountName
# Steadfast Conference Invoice_172  Nov 2021
# Line:  T1	ABN 117 131	29 124 799 042
#
# 111 125 ABN
# Line:  T2	BSB 795 802	182 222
#
# 741 748 BSB
# Line:  T3	AccountNum 821 831	3034-15129
#
# 765 775 AccountNum
# Line:  T4	SwiftCode 846 854	MACQAU2S
#
# 788 796 SwiftCode
# Line:  T5	BankName 773 787	Macquarie Bank
#
# 721 735 BankName
# Line:  T6	AccountName 736 764	Steadfast Convention Pty Ltd
#
# 25 53 AccountName
# TTAU2021081279-INSURANCE AUSTRALIA LIMITED-invoice
# Line:  T1	ABN 91 105	15 637 464 638
#
# 88 102 ABN
# Line:  T2	ABN 379 393	11 000 016 722
#
# 357 371 ABN
# Line:  T3	SwiftCode 855 863	CITIAU2X
#
# 809 817 SwiftCode
# Line:  T4	AccountNum 789 801	100763
#
# 751 757 AccountNum
# Line:  T5	BankName 741 755	Citibank, N.A.
#
# 698 712 BankName
# Line:  T6	AccountName 817 841	TIKTOK AUSTRALIA PTY LTD
#
# 0 24 AccountName
# Line:  T7	BSB 921 927	248037
#
# 745 751 BSB
# Tax Invoice 114876 - [13133] IP Australia website BAU Support (21-22)
# Line:  T1	BSB 702 708	083321
#
# 671 677 BSB
# Line:  T2	AccountNum 721 730	563080905
#
# 690 699 AccountNum
# Line:  T3	AccountName 671 696	Iconinc Holdings Pty Ltd.
#
# 640 665 AccountName
# Line:  T4	ABN 553 567	12 103 086 451
#
# 151 165 ABN
# Line:  T5	ABN 162 176	12 103 086 451
#
# 151 165 ABN
# Tax Invoice-INV7220
# Line:  T1	BankName 661 691	Commonwealth Bank of Australia
#
# 614 644 BankName
# Line:  T2	AccountName 772 800	THINKPLACE AUSTRALIA PTY LTD
#
# 723 751 AccountName
# Line:  T3	SwiftCode 903 911	CTBAAU2S
#
# 851 859 SwiftCode
# Line:  T4	AccountNum 870 885	062900 11169707
#
# 819 834 AccountNum
# Line:  T5	AccountNum 837 846	1705 8088
#
# 787 796 AccountNum
# Line:  T6	BSB 813 820	062-000
#
# 763 770 BSB
# Line:  T7	ABN 302 316	56 625 156 845
#
# 280 294 ABN
# TaxInvoice_FTI_FTF00008712_IPAUS -00_IP Australia_03-Feb-2022
# Line:  T1	ABN 146 157	42063577739
#
# 136 147 ABN
# Line:  T2	AccountNum 797 806	620406052
#
# 741 750 AccountNum
# Line:  T3	BSB 778 785	082080
#
# -1 5 BSB
# Line:  T4	BankName 752 770	National Aust Bank
#
# 699 717 BankName
# Line:  T5	AccountName 701 727	Canon Business Services Australia Pty Ltd
#
# 46 87 AccountName
# Workdynamic invoice 18.10.21
# Line:  T1	ABN 193 207	51 138 611 239
#
# 176 190 ABN
# Line:  T2	AccountNum 2945 2954	962304275
#
# 2874 2883 AccountNum
# Line:  T3	BSB 2924 2931	182-512
#
# 2854 2861 BSB
# ZDN0203991
# Line:  T1	BSB 896 903	034 081
#
# 833 840 BSB
# Line:  T2	AccountNum 1018 1025	311 286
#
# 949 956 AccountNum
# Line:  T3	ABN 1706 1720	67 005 944 203
#
# 79 93 ABN
# Line:  T4	ABN 1768 1782	58 161 858 788
#
# 161 175 ABN
# [62432] IP Australia Skybridge Sign 2
# Line:  T1	ABN 246 260	95 060 811 725
#
# 229 243 ABN
# Line:  T2	AccountNum 1175 1184	1006 2364
#
# 1137 1146 AccountNum
# Line:  T3	BSB 1148 1155	062 909
#
# 1110 1117 BSB
# Line:  T4	AccountName 1094 1120	Swell Design Group Pty Ltd
#
# 18 44 AccountName
# 00660357
# Line:  T1	BSB 702 709	332-056
#
# 645 652 BSB
# Line:  T2	AccountNum 718 726	55347866
#
# 661 669 AccountNum
# Line:  T3	ABN 150 161	17078782537
#
# 143 154 ABN
# 700745
# Line:  T1	ABN 239 250	43093709749
#
# 226 237 ABN
# Line:  T2	SwiftCode 1782 1793	BNPAAU2SXXX
#
# 1689 1700 SwiftCode
# Line:  T3	AccountNum 1764 1773	201097001
#
# 1672 1681 AccountNum
# Line:  T4	BSB 1715 1722	222 200
#
# 1626 1633 BSB
# 91026558
# Line:  T1	ABN 1518 1532	97 164 598 120
#
# 1447 1461 ABN
# Line:  T2	BSB 1176 1183	082-057
#
# 1108 1115 BSB
# Line:  T3	AccountNum 1196 1205	974252919
#
# 1128 1137 AccountNum
# I001132
# Line:  T1	ABN 102 116	12 080 534 005
#
# 97 111 ABN
# Line:  T2	AccountName 1181 1209	Bevington Consulting Pty Ltd
#
# 1008 1036 AccountName
# Line:  T3	BSB 1217 1224	013 445
#
# 1162 1169 BSB
# Line:  T4	AccountNum 1243 1254	493 856 711
#
# 1186 1197 AccountNum
# INV00009592
# Line:  T1	ABN 74 88	12 497 045 671
#
# 70 84 ABN
# Line:  T2	BSB 578 584	062904
#
# 536 542 BSB
# Line:  T3	BankName 586 603	Commonwealth Bank
#
# 543 560 BankName
# Line:  T4	AccountNum 536 544	10369642
#
# 496 504 AccountNum
# Line:  T5	AccountName 468 486	Infinity Engraving
#
# 430 448 AccountName
# IP Australia - EAP January 2022
# Line:  T1	ABN 186 200	74 599 608 295
#
# 178 192 ABN
# Line:  T2	BSB 1048 1055	092-009
#
# 992 999 BSB
# Line:  T3	AccountNum 1103 1109	118689
#
# 1044 1050 AccountNum
# Line:  T4	SwiftCode 1131 1139	RSBKAU2S
#
# 1069 1077 SwiftCode
# Line:  T5	AccountName 984 1037	Department of Industry, Science, Energy and Resources
#
# 930 983 AccountName
# Line:  T6	BankName 718 743	Reserve Bank of Australia
#
# 674 699 BankName
# IP Australia 45349 [IPSAGR] [0339BL]
# Line:  T1	ABN 126 140	19 002 966 001
#
# 121 135 ABN
# Line:  T2	AccountNum 1170 1179	232874015
#
# 1116 1125 AccountNum
# Line:  T3	BSB 1158 1165	242-000
#
# 1104 1111 BSB
# Invoice INV-0529
# Line:  T1	ABN 329 343	97 414 746 779
#
# 307 321 ABN
# Line:  T2	BSB 692 699	032-135
#
# 648 655 BSB
# Line:  T3	AccountNum 705 712	594 834
#
# 661 668 AccountNum
# Line:  T4	AccountName 643 685	mwah. Making Work Absolutely Human Pty Ltd
#
# 600 642 AccountName
# Invoice INV-09820006
# Line:  T1	ABN 317 331	38 113 072 755
#
# 298 312 ABN
# Line:  T2	ABN 338 352	71 618 216 390
#
# 317 331 ABN
# Line:  T3	BSB 804 811	032 713
#
# 799 806 BSB
# Line:  T4	AccountNum 825 832	453 989
#
# 818 825 AccountNum
# Line:  T5	AccountName 773 797	Define Potential Pty Ltd
#
# 44 68 AccountName
# Invoice_AUS-2001826_1646021286516
# Line:  T1	SwiftCode 1045 1053	BOFAAUSX
#
# 981 989 SwiftCode
# Line:  T2	AccountNum 1085 1093	17159011
#
# 1019 1027 AccountNum
# Line:  T3	BSB 1060 1067	232 001
#
# 995 1002 BSB
# Line:  T4	AccountName 970 1000	Dynatrace Asia-Pacific Pty Ltd
#
# 908 938 AccountName
# Line:  T5	BankName 1016 1031	Bank of America
#
# 953 968 BankName
# Line:  T6	ABN 242 256	23 063 641 510
#
# 230 244 ABN
# Invoice_INV-42640
# Line:  T1	AccountNum 936 946	4122247414
#
# 880 890 AccountNum
# Line:  T2	SwiftCode 1095 1103	WFBIUS6S
#
# 1033 1041 SwiftCode
# Line:  T3	SwiftCode 1136 1147	WFBIUS6WFFX
#
# 1073 1084 SwiftCode
# Line:  T4	AccountNum 1029 1039	4122247414
#
# 880 890 AccountNum
# Line:  T5	BankName 995 1016	Wells Fargo Bank N.A.
#
# 936 957 BankName
# Line:  T6	ABN 232 243	13614231432
#
# 217 228 ABN
# Tax Invoice 31-01-2022
# Line:  T1	ABN 307 321	28 864 970 579
#
# 295 309 ABN
# Line:  T2	AccountNum 479 485	183004
#
# 456 462 AccountNum
# Line:  T3	BSB 3266 3273	064-787
#
# 3099 3106 BSB
# Line:  T4	AccountNum 3303 3309	183004
#
# 456 462 AccountNum
# Zepp _ Co Paul Pittioni estimate
# Line:  T1	SwiftCode 653 661	WPACAU2S
#
# 610 618 SwiftCode
# Line:  T2	AccountNum 632 639	368-840
#
# 590 597 AccountNum
# Line:  T3	BSB 611 618	032-090
#
# 570 577 BSB
# Line:  T4	AccountName 587 604	Zepp & Co Pty Ltd
#
# 60 77 AccountName
# Line:  T5	BankName 568 575	Westpac
#
# 529 536 BankName
# Line:  T6	ABN 235 249	72 104 433 356
#
# 217 231 ABN

# %%
TRAIN_DATA[12]#[1]['entities']
# Out:
# ("TIKTOK AUSTRALIA PTY LTD\nAddress: Level 10, 68 Pitt Street, Sydney NSW 2000\nTikTok\nABN: 15 637 464 638\nTAX INVOICE\nBill To\nClient Name:\nINSURANCE AUSTRALIA LIMITED\nInvoice #:\nTTAU2021081279\nClient ID:\n6993126001425253121\nInvoice Date:\n05, December, 2021\nBilling Contact:\nDue Date:\n04, January, 2022\nBilling Email:\nContract #:\nCON6508843\nBilling Tel:\nABN #:\n11 000 016 722\nBilling Address:\nDarling Park, Tower Two, 201 Sussex St, Sydney\nNSW, SYDNEY, NSW 2000\nBilling Period\n30, November, 2021 ~ 30, November, 2021\nAdvertiser Name\nDescription\nNote\nAmount in AUD\nROLLiN' | Auction\nAdvertising Fees\n6,923.21\nRemarks:\nSubtotal\n6,923.21\nGST@10%\n692.32\nTotal incl. GST\n7,615.53\nPayment method:\nBank Name: Citibank, N.A. (Sydney Branch)\nAccount Number: 248037100763\nAccount Name: TIKTOK AUSTRALIA PTY LTD\nSWIFT Code: CITIAU2X\nBank Address: 2 Park Street, SYDNEY NSW 2000\nBSB Code: 248037\nFor domestic AUD transfers, please use the last 6 digits of the account number as displayed above.\nFor NZD/USD or international AUD transfers, please use the full 12 digits of the account number as displayed above and the SWFIT code.\nFor example: Full account number is 248037100005. For domestic transfers AUD, please use BSB 248037, Account number 100005. For\nNZD/USD or international AUD transfer, please use 248037100005 and SWIFT code CITIAU2X\nINVOICE NUMBER MUST BE REFERENCED ON ALL PAYMENTS\nThank You for Your Business\nConsumption Details:\nInvoice Number: TTAU2021081279\nRefer to Report: ST1007870383\nStatement\nAdvertiser\nAdvertiser\nCampaign\nTarget\nPO#\nPeriod\nTotal\nCash\nID\nCountr\nConsumptio\nConsumptio\ny\nn AUD\nn AUD\nST1007870\nROLLiN' |\n70269575\nFY21_ROLLIN'_\nAU\n2021-\n6,923.21\n6,923.21\n383\nAuction\n23445940\nNOV-\n11-30 ~\n226\nDEC_LAUNCH\n2021-\nCAMPAIGN\n11-30\nNATIONAL_BRA\nND\nAWARENESS_TI\nKTOK\nSubtotal in\n6,923.21\nAUD\nGST@10.0%\n692.32\nTotal in AUD\n7,615.53\nPlease note that if sum up multiple statements, there will exist some amount differences due to round up. Please take total\namount in invoice as final confirmed payment amount.\n",
#  {'entities': [(745, 757, 'AccountNum'),
#    (745, 751, 'BSB'),
#    (698, 712, 'BankName'),
#    (357, 371, 'ABN'),
#    (809, 817, 'SwiftCode'),
#    (88, 102, 'ABN'),
#    (0, 24, 'AccountName')]})

# %%
trained_model = train(TRAIN_DATA, num_epochs=50)
# Out:
# Losses {'ner': 85.29296957739122}
# Losses {'ner': 64.03043944574893}
# Losses {'ner': 56.49548473006598}
# Losses {'ner': 19.693392547642816}
# Losses {'ner': 18.20112617250193}
# Losses {'ner': 11.726825103465671}
# Losses {'ner': 19.149596950528917}
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "Tax Invoice
# Icon Agency
# IP Australia
# INVOICE NUMBE..." with entities "[(671, 677, 'BSB'), (640, 665, 'AccountName'), (15...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 10.763713662491543}
# Losses {'ner': 9.727037744610602}
# Losses {'ner': 12.011854553900081}
# Losses {'ner': 8.237378467402348}
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "NTT
# Copy of Tax Invoice
# NTT Australia Pty Ltd
# Tran..." with entities "[(1114, 1132, 'AccountName'), (1153, 1162, 'Accoun...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 6.661388276567594}
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "KONDININ
# GROUP
# TAX INVOICE
# Invoice Date
# Kondinin I..." with entities "[(1409, 1420, 'AccountNum'), (352, 366, 'ABN'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 9.990165076615535}
# Losses {'ner': 6.767715774055091}
# Losses {'ner': 8.106728238714282}
# Losses {'ner': 6.915874581239542}
# Losses {'ner': 67.83521580696106}
# Losses {'ner': 7.769754349036134}
# Losses {'ner': 8.20802305532925}
# Losses {'ner': 7.6275565052501975}
# Losses {'ner': 10.535300221152283}
# Losses {'ner': 8.080054103291332}
# Losses {'ner': 6.039320661202407}
# Losses {'ner': 9.322375862328263}
# Losses {'ner': 8.194266718674115}
# Losses {'ner': 7.60308397659287}
# Losses {'ner': 6.977751027463341}
# Losses {'ner': 9.829424573451423}
# Losses {'ner': 7.373369495766951}
# Losses {'ner': 2.3728595822904026}
# Losses {'ner': 11.177932791665853}
# Losses {'ner': 3.9652208419938386}
# Losses {'ner': 5.547767163619696}
# Losses {'ner': 5.455694787233746}
# Losses {'ner': 11.682963295813881}
# Losses {'ner': 9.944055961691019}
# Losses {'ner': 9.404856976704195}
# Losses {'ner': 11.895720165246018}
# Losses {'ner': 9.458188146724751}
# Losses {'ner': 9.54341474181578}
# Losses {'ner': 6.903888657034258}
# Losses {'ner': 11.99132384021328}
# Losses {'ner': 5.589451901966655}
# Losses {'ner': 7.018590051794945}
# Losses {'ner': 10.770737073040651}
# Losses {'ner': 9.238560019159195}
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text " GOLOGIC
# TAX INVOICE
# Invoice Date
# GoLogic Group Pt..." with entities "[(761, 769, 'SwiftCode'), (715, 718, 'BankName'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "TIKTOK AUSTRALIA PTY LTD
# Address  Level 10  68 Pit..." with entities "[(751, 757, 'AccountNum'), (809, 817, 'SwiftCode')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 7.125831763492897}
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "Canon
# Tax Invoice
# CANON BUSINESS
# SERVICES ANZ
# Cano..." with entities "[(741, 750, 'AccountNum'), (-1, 5, 'BSB'), (699, 7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': 8.075151186454129}
# Losses {'ner': 11.19765164402017}
# Losses {'ner': 4.810797416543664}
# Losses {'ner': 5.732436612645873}
# Losses {'ner': 6.4351475873477995}
# Losses {'ner': 6.955632027588329}
# Losses {'ner': 7.276399400923053}
# Losses {'ner': 8.444710301542695}
# Losses {'ner': 5.635435600537058}
# Losses {'ner': 10.832310450425963}
# Losses {'ner': 4.682520892570387}
# Losses {'ner': 7.23650774103726}
# Losses {'ner': 12.879228573758725}
# Losses {'ner': 6.611304068920639}
# Losses {'ner': 5.423648982083994}
# Losses {'ner': 76.48776428690012}
# Losses {'ner': 3.5298105564515816}
# Losses {'ner': 6.848746678557433}
# Losses {'ner': 8.14148069677995}
# Losses {'ner': 8.494690454994936}
# Losses {'ner': 5.037252211117524}
# Losses {'ner': 58.16483703681577}
# Losses {'ner': 108.16311550140381}
# Losses {'ner': 66.20893088824397}
# Losses {'ner': 91.6432667744558}
# Losses {'ner': 25.483910057844263}
# Losses {'ner': 38.10747445611388}
# Losses {'ner': 25.80756020325717}
# Losses {'ner': 10.749580182928952}
# Losses {'ner': 14.085363208081777}
# Losses {'ner': 8.073009892143897}
# Losses {'ner': 7.068572179654737}
# Losses {'ner': 2.2650719332693825}
# Losses {'ner': 114.38474786281586}
# Losses {'ner': 3.636994519517545}
# Losses {'ner': 4.32192100885587}
# Losses {'ner': 4.6563947888903385}
# Losses {'ner': 10.353520323025938}
# Losses {'ner': 11.777994571821313}
# Losses {'ner': 10.25291203568661}
# Losses {'ner': 11.838516495676203}
# Losses {'ner': 10.28733223878277}
# Losses {'ner': 8.071239504275042}
# Losses {'ner': 7.566228240931406}
# Losses {'ner': 12.993503987182853}
# Losses {'ner': 5.3227528696309605}
# Losses {'ner': 9.400591464518584}
# Losses {'ner': 7.950515360673344}
# Losses {'ner': 9.02453143454008}
# Losses {'ner': 7.178432620952657}
# Losses {'ner': 7.6877183748689575}
# Losses {'ner': 16.429311425557806}
# Losses {'ner': 3.8464136408003924}
# Losses {'ner': 6.508040712185505}
# Losses {'ner': 26.442200851015492}
# Losses {'ner': 11.325133330806663}
# Losses {'ner': 6.438818163051128}
# Losses {'ner': 13.41536344771356}
# Losses {'ner': 8.502443884641892}
# Losses {'ner': 9.658114295574837}
# Losses {'ner': 6.688622750527486}
# Losses {'ner': 6.173832998143681}
# Losses {'ner': 10.03641097637224}
# Losses {'ner': 6.118555113928721}
# Losses {'ner': 3.8274548468702165}
# Losses {'ner': 7.764992431859696}
# Losses {'ner': 3.754679096283409}
# Losses {'ner': 6.406133363521178}
# Losses {'ner': 4.910589840122725}
# Losses {'ner': 9.23082504079207}
# Losses {'ner': 5.390050907888476}
# Losses {'ner': 9.284167519522455}
# Losses {'ner': 6.434863930322109}
# Losses {'ner': 7.278815888222762}
# Losses {'ner': 5.758831068137661}
# Losses {'ner': 4.489273023069624}
# Losses {'ner': 8.158193584566801}
# Losses {'ner': 6.395400464994901}
# Losses {'ner': 7.186499645005785}
# Losses {'ner': 7.214002328954674}
# Losses {'ner': 8.698041528146343}
# Losses {'ner': 7.664112779896161}
# Losses {'ner': 1.9589535959885112}
# Losses {'ner': 10.858019422798288}
# Losses {'ner': 2.9837368123552483}
# Losses {'ner': 4.034966109866087}
# Losses {'ner': 3.871112876289327}
# Losses {'ner': 8.595980119303505}
# Losses {'ner': 9.574848890534678}
# Losses {'ner': 9.815593761147028}
# Losses {'ner': 10.77964266129932}
# Losses {'ner': 12.33325006112877}
# Losses {'ner': 5.768291128544599}
# Losses {'ner': 7.097133653274582}
# Losses {'ner': 8.919626449218125}
# Losses {'ner': 3.307708011995153}
# Losses {'ner': 9.079485059282758}
# Losses {'ner': 6.371793502213983}
# Losses {'ner': 7.410344787499063}
# Losses {'ner': 7.978659358951557}
# Losses {'ner': 5.784621967315516}
# Losses {'ner': 13.252990078780172}
# Losses {'ner': 182.1816947992549}
# Losses {'ner': 5.274813481818026}
# Losses {'ner': 5.991052323273851}
# Losses {'ner': 6.729750307156358}
# Losses {'ner': 5.566154159923459}
# Losses {'ner': 7.280539984457867}
# Losses {'ner': 5.033026300444913}
# Losses {'ner': 7.338819319597594}
# Losses {'ner': 5.0807287487520245}
# Losses {'ner': 11.212349469143458}
# Losses {'ner': 7.537023479868217}
# Losses {'ner': 5.379322639023442}
# Losses {'ner': 4.563896351035137}
# Losses {'ner': 6.520018676007891}
# Losses {'ner': 2.3735855098913845}
# Losses {'ner': 5.721549073830303}
# Losses {'ner': 2.7949517710291105}
# Losses {'ner': 7.613644718706771}
# Losses {'ner': 3.911528392894459}
# Losses {'ner': 6.417584221270934}
# Losses {'ner': 3.9727690415064947}
# Losses {'ner': 5.631294364695947}
# Losses {'ner': 5.52414136946868}
# Losses {'ner': 4.580567375328424}
# Losses {'ner': 5.598014493005138}
# Losses {'ner': 21.392614998070066}
# Losses {'ner': 4.7669505670231835}
# Losses {'ner': 5.15401729165114}
# Losses {'ner': 7.016807235872788}
# Losses {'ner': 6.763131910035801}
# Losses {'ner': 1.427874186519852}
# Losses {'ner': 92.36368936300278}
# Losses {'ner': 3.0381589844415666}
# Losses {'ner': 1.9925086808361334}
# Losses {'ner': 3.011283222084591}
# Losses {'ner': 9.009135930962175}
# Losses {'ner': 6.0692937525800925}
# Losses {'ner': 4.823833947352959}
# Losses {'ner': 8.764597754320956}
# Losses {'ner': 9.788028234586594}
# Losses {'ner': 5.719789591162256}
# Losses {'ner': 3.7120191806651412}
# Losses {'ner': 5.963023906588164}
# Losses {'ner': 2.7585545527659647}
# Losses {'ner': 13.314117085975328}
# Losses {'ner': 10.94077941619488}
# Losses {'ner': 8.89882506600194}
# Losses {'ner': 9.190022851297465}
# Losses {'ner': 5.675752201701956}
# Losses {'ner': 11.147789691292871}
# Losses {'ner': 2.5280462899012264}
# Losses {'ner': 4.59811789107147}
# Losses {'ner': 6.125237188374141}
# Losses {'ner': 8.442752104696984}
# Losses {'ner': 4.363437312664232}
# Losses {'ner': 6.134880602731157}
# Losses {'ner': 3.4682448669294663}
# Losses {'ner': 4.799708209115032}
# Losses {'ner': 3.57723671454879}
# Losses {'ner': 4.761063238882814}
# Losses {'ner': 5.4064429882509435}
# Losses {'ner': 6.833336854581207}
# Losses {'ner': 4.411190247402257}
# Losses {'ner': 4.201016400642638}
# Losses {'ner': 1.1565120394997552}
# Losses {'ner': 3.0895088214000834}
# Losses {'ner': 0.8341829782573253}
# Losses {'ner': 6.618542247156793}
# Losses {'ner': 2.009334723404766}
# Losses {'ner': 106.54009789412007}
# Losses {'ner': 2.4270219671977333}
# Losses {'ner': 3.527643137673384}
# Losses {'ner': 2.8798975407335146}
# Losses {'ner': 1.2797063479266415}
# Losses {'ner': 21.33637397242557}
# Losses {'ner': 5.999706026471509}
# Losses {'ner': 5.071342691365007}
# Losses {'ner': 4.198310523722229}
# Losses {'ner': 8.132320428641702}
# Losses {'ner': 3.8991109712960044}
# Losses {'ner': 1.7931324885936275}
# Losses {'ner': 10.138374218793063}
# Losses {'ner': 2.5528227781806616}
# Losses {'ner': 1.3667104350036574}
# Losses {'ner': 2.9335111205777022}
# Losses {'ner': 6.769630181531838}
# Losses {'ner': 4.890331861047489}
# Losses {'ner': 2.2378348042056992}
# Losses {'ner': 10.862378343880646}
# Losses {'ner': 11.573934578117079}
# Losses {'ner': 6.123652455358828}
# Losses {'ner': 5.174187563358904}
# Losses {'ner': 5.407502075551434}
# Losses {'ner': 1.7247123227446357}
# Losses {'ner': 6.741536484455715}
# Losses {'ner': 4.108209967832154}
# Losses {'ner': 109.69563708269501}
# Losses {'ner': 4.273195347107232}
# Losses {'ner': 4.29235651368416}
# Losses {'ner': 87.50984010646282}
# Losses {'ner': 0.5783074267260235}
# Losses {'ner': 5.152695122841727}
# Losses {'ner': 3.0489611068141738}
# Losses {'ner': 6.88057294050955}
# Losses {'ner': 3.6421151722836522}
# Losses {'ner': 62.515839742925216}
# Losses {'ner': 4.206666621070238}
# Losses {'ner': 5.5848791430879565}
# Losses {'ner': 4.522280843404029}
# Losses {'ner': 7.336754509030704}
# Losses {'ner': 4.997372600994632}
# Losses {'ner': 4.422154898718092}
# Losses {'ner': 0.9967143567327488}
# Losses {'ner': 4.078873015004583}
# Losses {'ner': 0.7692813077307165}
# Losses {'ner': 3.965854122852498}
# Losses {'ner': 0.42488522381917004}
# Losses {'ner': 6.113855820333353}
# Losses {'ner': 3.350727333530029}
# Losses {'ner': 3.935868943479423}
# Losses {'ner': 1.261842165825991}
# Losses {'ner': 5.083959662345253}
# Losses {'ner': 7.165798723647239}
# Losses {'ner': 3.8024438550724717}
# Losses {'ner': 4.975896513978411}
# Losses {'ner': 4.063255809778279}
# Losses {'ner': 4.5815041318732685}
# Losses {'ner': 5.923686183130837}
# Losses {'ner': 6.10205469666612}
# Losses {'ner': 3.982604610059928}
# Losses {'ner': 2.1780220565583153}
# Losses {'ner': 6.830195461368246}
# Losses {'ner': 1.2404188788418098}
# Losses {'ner': 1.2799028501675571}
# Losses {'ner': 1.6077926941047629}
# Losses {'ner': 5.739499317318661}
# Losses {'ner': 6.098795626237202}
# Losses {'ner': 3.178178647252368}
# Losses {'ner': 6.902483119475525}
# Losses {'ner': 9.09167194093391}
# Losses {'ner': 4.4333213205873685}
# Losses {'ner': 2.920250238629344}
# Losses {'ner': 2.500428250005201}
# Losses {'ner': 0.9731884776460948}
# Losses {'ner': 5.164013718549855}
# Losses {'ner': 5.38069510496593}
# Losses {'ner': 8.916005540506024}
# Losses {'ner': 3.850140190020282}
# Losses {'ner': 3.9814276424340855}
# Losses {'ner': 9.435218986179228}
# Losses {'ner': 0.8720929119484382}
# Losses {'ner': 3.143008401560336}
# Losses {'ner': 2.3347730233191553}
# Losses {'ner': 5.295968350609291}
# Losses {'ner': 3.4258081009310133}
# Losses {'ner': 3.6110845667231177}
# Losses {'ner': 3.9427159317565836}
# Losses {'ner': 2.9542966075961603}
# Losses {'ner': 3.3691988254017056}
# Losses {'ner': 4.8370079359288205}
# Losses {'ner': 5.6347413767924355}
# Losses {'ner': 4.7369440673842265}
# Losses {'ner': 6.549174352723602}
# Losses {'ner': 6.106842987439297}
# Losses {'ner': 0.7989923978191966}
# Losses {'ner': 1.3906050463487596}
# Losses {'ner': 1.9054756229789758}
# Losses {'ner': 5.720263279864459}
# Losses {'ner': 1.89008431498869}
# Losses {'ner': 6.994929145047399}
# Losses {'ner': 0.4787993480901288}
# Losses {'ner': 2.4274842383802744}
# Losses {'ner': 1.7151723351087282}
# Losses {'ner': 2.601834392631686}
# Losses {'ner': 17.89979711231701}
# Losses {'ner': 3.3161591680483813}
# Losses {'ner': 3.2987478327133326}
# Losses {'ner': 3.749741225094649}
# Losses {'ner': 3.8050859151216256}
# Losses {'ner': 1.2550971900006913}
# Losses {'ner': 1.2846484915045298}
# Losses {'ner': 6.322802518755076}
# Losses {'ner': 1.1505639755882549}
# Losses {'ner': 1.3900018918270352}
# Losses {'ner': 1.041632911823856}
# Losses {'ner': 3.139607616993939}
# Losses {'ner': 1.8208604994140853}
# Losses {'ner': 1.1443702857698854}
# Losses {'ner': 6.2625329154390235}
# Losses {'ner': 7.767200835309538}
# Losses {'ner': 6.538972683343605}
# Losses {'ner': 1.9253147248896751}
# Losses {'ner': 3.3825232674976964}
# Losses {'ner': 3.081183185974151}
# Losses {'ner': 2.854688059604003}
# Losses {'ner': 3.973089290492225}
# Losses {'ner': 4.766250258742389}
# Losses {'ner': 2.504652601399425}
# Losses {'ner': 2.9202008287144063}
# Losses {'ner': 12.49042035513573}
# Losses {'ner': 0.3004188407613362}
# Losses {'ner': 2.443249396871389}
# Losses {'ner': 2.966924046097138}
# Losses {'ner': 4.662883723522822}
# Losses {'ner': 2.02585443454592}
# Losses {'ner': 4.913308438072682}
# Losses {'ner': 3.7332508936053963}
# Losses {'ner': 4.410774262637977}
# Losses {'ner': 3.071164438256018}
# Losses {'ner': 2.004512402581219}
# Losses {'ner': 7.023341901644215}
# Losses {'ner': 2.691786149149092}
# Losses {'ner': 26.34777404569857}
# Losses {'ner': 28.019954490195612}
# Losses {'ner': 0.727127288381028}
# Losses {'ner': 2.3627327534714047}
# Losses {'ner': 0.17464585053385384}
# Losses {'ner': 5.924929238076532}
# Losses {'ner': 0.973051337589812}
# Losses {'ner': 5.268629135242294}
# Losses {'ner': 2.8580266523533013}
# Losses {'ner': 6.602986685414265}
# Losses {'ner': 28.732529238061787}
# Losses {'ner': 1.0199990628722984}
# Losses {'ner': 7.758255585337193}
# Losses {'ner': 1.8446664275267501}
# Losses {'ner': 1.312982085452656}
# Losses {'ner': 7.938760206070397}
# Losses {'ner': 13.855373123067533}
# Losses {'ner': 1.5755701596114378}
# Losses {'ner': 1.9157528992569193}
# Losses {'ner': 9.218420473557869}
# Losses {'ner': 0.3129961411413696}
# Losses {'ner': 1.0782956727221562}
# Losses {'ner': 1.7537350287921691}
# Losses {'ner': 16.206429286494767}
# Losses {'ner': 3.405639484585906}
# Losses {'ner': 3.408732690337048}
# Losses {'ner': 8.474121765646816}
# Losses {'ner': 10.148004963925866}
# Losses {'ner': 3.828664837661759}
# Losses {'ner': 1.2117487278674184}
# Losses {'ner': 3.456084654914192}
# Losses {'ner': 0.5215362732885815}
# Losses {'ner': 4.764077425943821}
# Losses {'ner': 4.0051794852556055}
# Losses {'ner': 3.516969189789262}
# Losses {'ner': 4.82206656056807}
# Losses {'ner': 3.72742015071311}
# Losses {'ner': 10.908291355222989}
# Losses {'ner': 0.08877909685071979}
# Losses {'ner': 2.786312123877325}
# Losses {'ner': 1.3018125961056943}
# Losses {'ner': 4.334787398356158}
# Losses {'ner': 4.1032018986437695}
# Losses {'ner': 2.652494129225398}
# Losses {'ner': 1.8680626461482683}
# Losses {'ner': 2.97189066808633}
# Losses {'ner': 2.478016042618181}
# Losses {'ner': 4.6739694588230325}
# Losses {'ner': 2.3991047778797405}
# Losses {'ner': 2.2356887847772415}
# Losses {'ner': 2.896337791625994}
# Losses {'ner': 4.464269925235023}
# Losses {'ner': 0.2985855418498299}
# Losses {'ner': 1.694180253356376}
# Losses {'ner': 2.4563146953966624}
# Losses {'ner': 6.664763272259371}
# Losses {'ner': 1.4403701312396326}
# Losses {'ner': 4.528139673700029}
# Losses {'ner': 0.587525676338805}
# Losses {'ner': 3.944829579157788}
# Losses {'ner': 1.5021978959459665}
# Losses {'ner': 2.197936603695889}
# Losses {'ner': 4.021878656014577}
# Losses {'ner': 0.8717828573168597}
# Losses {'ner': 0.2898725503355739}
# Losses {'ner': 4.602283972039122}
# Losses {'ner': 7.342502216650685}
# Losses {'ner': 4.298789769600792}
# Losses {'ner': 2.562819996887833}
# Losses {'ner': 6.658688464291461}
# Losses {'ner': 0.24111786818700814}
# Losses {'ner': 2.0356585572555144}
# Losses {'ner': 1.648934164944896}
# Losses {'ner': 2.259941179362992}
# Losses {'ner': 5.090648494094543}
# Losses {'ner': 1.7158625024199696}
# Losses {'ner': 5.8970536218775}
# Losses {'ner': 6.433691398853503}
# Losses {'ner': 4.172554623688267}
# Losses {'ner': 2.097948858137803}
# Losses {'ner': 2.859439238486829}
# Losses {'ner': 1.1311796971532972}
# Losses {'ner': 2.4824973527453715}
# Losses {'ner': 3.3469610656927533}
# Losses {'ner': 3.3914856907799864}
# Losses {'ner': 1.8443911219762164}
# Losses {'ner': 2.8837039597224843}
# Losses {'ner': 7.353761934778014}
# Losses {'ner': 1.2751185287250546}
# Losses {'ner': 3.2634986713558556}
# Losses {'ner': 1.8203529770179325}
# Losses {'ner': 3.9249169558131802}
# Losses {'ner': 1.6745886691837528}
# Losses {'ner': 15.953043176334832}
# Losses {'ner': 2.068300908220641}
# Losses {'ner': 3.250991458818806}
# Losses {'ner': 2.2959930389346006}
# Losses {'ner': 6.967574459804893}
# Losses {'ner': 3.5092715558892085}
# Losses {'ner': 2.0682341853892265}
# Losses {'ner': 1.5271521316258059}
# Losses {'ner': 6.692760140737984}
# Losses {'ner': 0.07908674757014002}
# Losses {'ner': 2.125377856384247}
# Losses {'ner': 0.4120117071440933}
# Losses {'ner': 1.617741486082377}
# Losses {'ner': 0.10785866651434013}
# Losses {'ner': 3.9205563038150584}
# Losses {'ner': 0.7756790627148369}
# Losses {'ner': 4.9518883518279635}
# Losses {'ner': 4.723486428664537}
# Losses {'ner': 0.369398852948913}
# Losses {'ner': 2.4899296542023444}
# Losses {'ner': 3.5825418003408127}
# Losses {'ner': 0.22250930915662873}
# Losses {'ner': 3.5660211994177105}
# Losses {'ner': 7.8609665773548825}
# Losses {'ner': 4.138344879177013}
# Losses {'ner': 0.41855907299099987}
# Losses {'ner': 3.619309296467779}
# Losses {'ner': 0.4457682727648897}
# Losses {'ner': 1.3244698406998217}
# Losses {'ner': 2.3440716420228793}
# Losses {'ner': 2.0530438425590156}
# Losses {'ner': 4.694323781866488}
# Losses {'ner': 2.7591899306226724}
# Losses {'ner': 8.08858988611623}
# Losses {'ner': 5.651853690360312}
# Losses {'ner': 4.584983789684297}
# Losses {'ner': 3.9445386830220106}
# Losses {'ner': 1.8152125334279645}
# Losses {'ner': 2.3805639328339696}
# Losses {'ner': 1.8797987775300964}
# Losses {'ner': 4.621438195252434}
# Losses {'ner': 0.765093450448859}
# Losses {'ner': 3.745702362489189}
# Losses {'ner': 3.224884276583837}
# Losses {'ner': 12.13873866001442}
# Losses {'ner': 0.010679145491405096}
# Losses {'ner': 2.2720984186364825}
# Losses {'ner': 0.05510561987628532}
# Losses {'ner': 4.14294198133774}
# Losses {'ner': 1.8880209218593165}
# Losses {'ner': 1.9240985599673073}
# Losses {'ner': 2.0115075787785104}
# Losses {'ner': 1.694293399868236}
# Losses {'ner': 0.40185998249268706}
# Losses {'ner': 5.482459775364}
# Losses {'ner': 2.6452740688877046}
# Losses {'ner': 2.356680223167274}
# Losses {'ner': 2.124825994924275}
# Losses {'ner': 2.3334110170150977}
# Losses {'ner': 0.1803440612107019}
# Losses {'ner': 1.7081820333793492}
# Losses {'ner': 0.016790112427921902}
# Losses {'ner': 0.7132098182650248}
# Losses {'ner': 0.04193246134051037}
# Losses {'ner': 2.410218300506225}
# Losses {'ner': 0.04773392525942804}
# Losses {'ner': 5.160918988141267}
# Losses {'ner': 4.290899452808723}
# Losses {'ner': 0.45990424915991696}
# Losses {'ner': 1.659600226809447}
# Losses {'ner': 1.8822870124350082}
# Losses {'ner': 0.1610579392390316}
# Losses {'ner': 2.767745180911941}
# Losses {'ner': 4.439549338534145}
# Losses {'ner': 0.23438384718614402}
# Losses {'ner': 1.9931908211025506}
# Losses {'ner': 5.126209279488239}
# Losses {'ner': 0.10528844222395722}
# Losses {'ner': 0.8876062432440439}
# Losses {'ner': 2.033712089570674}
# Losses {'ner': 1.9238128605895188}
# Losses {'ner': 4.302890121845112}
# Losses {'ner': 1.2076152991607119}
# Losses {'ner': 3.956185780704649}
# Losses {'ner': 8.775627645831301}
# Losses {'ner': 3.3741657039394166}
# Losses {'ner': 2.0936779590689527}
# Losses {'ner': 1.7275588765892091}
# Losses {'ner': 0.38719105141858395}
# Losses {'ner': 1.4944648102946623}
# Losses {'ner': 1.1137252363772259}
# Losses {'ner': 1.0877491311188732}
# Losses {'ner': 1.7365451155871434}
# Losses {'ner': 2.3115913688880942}
# Losses {'ner': 12.51548936331329}
# Losses {'ner': 0.0021006143527564167}
# Losses {'ner': 1.3219619926504378}
# Losses {'ner': 0.5308391485539714}
# Losses {'ner': 2.414030401408225}
# Losses {'ner': 1.134407623058744}
# Losses {'ner': 5.304924377053142}
# Losses {'ner': 1.9158634552014535}
# Losses {'ner': 1.9502767280946467}
# Losses {'ner': 1.1029262887336668}
# Losses {'ner': 5.125231412516843}
# Losses {'ner': 0.5370527234037233}
# Losses {'ner': 2.2026796269829205}
# Losses {'ner': 5.922361458842944}
# Losses {'ner': 5.2277594706959585}
# Losses {'ner': 0.3122785038140313}
# Losses {'ner': 1.6651705450945165}
# Losses {'ner': 0.0038178904112884005}
# Losses {'ner': 1.0383850730230242}
# Losses {'ner': 0.10397693337626311}
# Losses {'ner': 5.32834214898782}
# Losses {'ner': 0.1059714866770393}
# Losses {'ner': 5.694279940591057}
# Losses {'ner': 8.713836108262639}
# Losses {'ner': 1.9057606173842672}
# Losses {'ner': 2.397961332218629}
# Losses {'ner': 3.00462191973263}
# Losses {'ner': 0.20905621578051764}
# Losses {'ner': 3.407104595679099}
# Losses {'ner': 3.8487426935941476}
# Losses {'ner': 0.6507612568002511}
# Losses {'ner': 1.7006700231943617}
# Losses {'ner': 2.5141974635912}
# Losses {'ner': 0.0019320101178752233}
# Losses {'ner': 4.300142735336206}
# Losses {'ner': 0.02664809036674915}
# Losses {'ner': 4.401774702667181}
# Losses {'ner': 0.39591070236372444}
# Losses {'ner': 0.5362104375219464}
# Losses {'ner': 6.920525655989294}
# Losses {'ner': 6.720114467032193}
# Losses {'ner': 4.070222421193514}
# Losses {'ner': 1.8036610337118595}
# Losses {'ner': 1.9894994581889178}
# Losses {'ner': 0.0012697655258113996}
# Losses {'ner': 2.2204581245515387}
# Losses {'ner': 1.9774731281759048}
# Losses {'ner': 1.5040752639364117}
# Losses {'ner': 4.08374920076941}
# Losses {'ner': 1.2598156549020538}
# Losses {'ner': 8.648961429718794}
# Losses {'ner': 0.040229010789180855}
# Losses {'ner': 1.5957274035209779}
# Losses {'ner': 0.01870671323790615}
# Losses {'ner': 4.0947535053074775}
# Losses {'ner': 0.5053681801128616}
# Losses {'ner': 1.9332017282431873}
# Losses {'ner': 0.4276532903235857}
# Losses {'ner': 3.904118849369285}
# Losses {'ner': 2.2290527905453117}
# Losses {'ner': 3.5142095791111463}
# Losses {'ner': 2.5952874764558653}
# Losses {'ner': 1.0236462108916713}
# Losses {'ner': 4.107087695657674}
# Losses {'ner': 4.337425457442669}
# Losses {'ner': 0.008244901080195412}
# Losses {'ner': 2.2852414472219653}
# Losses {'ner': 0.49311533105788113}
# Losses {'ner': 2.0846095632413832}
# Losses {'ner': 0.14283887369393772}
# Losses {'ner': 3.9864587370093503}
# Losses {'ner': 1.0181273379315223}
# Losses {'ner': 6.902198105577791}
# Losses {'ner': 0.571362456158255}
# Losses {'ner': 0.7612860260214049}
# Losses {'ner': 2.47380388597963}
# Losses {'ner': 1.687835790042614}
# Losses {'ner': 2.1435054243775067}
# Losses {'ner': 3.295413355933733}
# Losses {'ner': 3.490415038686402}
# Losses {'ner': 0.16834370080997357}
# Losses {'ner': 2.053222904279188}
# Losses {'ner': 5.922966223642505}
# Losses {'ner': 0.41499233308037725}
# Losses {'ner': 0.033528089941894636}
# Losses {'ner': 1.0886214568974075}
# Losses {'ner': 1.9260969599296855}
# Losses {'ner': 2.717147574296292}
# Losses {'ner': 1.6327754924493467}
# Losses {'ner': 4.29205134465808}
# Losses {'ner': 2.833828976197763}
# Losses {'ner': 2.9271358428480196}
# Losses {'ner': 1.9856757267644203}
# Losses {'ner': 0.6773131193453142}
# Losses {'ner': 1.1288830302457296}
# Losses {'ner': 1.81681719939135}
# Losses {'ner': 2.59760194319195}
# Losses {'ner': 0.5234333801147217}
# Losses {'ner': 1.4567589874764781}
# Losses {'ner': 0.8370394170245681}
# Losses {'ner': 10.855448963883529}
# Losses {'ner': 0.00025833967064730815}
# Losses {'ner': 1.7867148395214847}
# Losses {'ner': 1.046179964717179}
# Losses {'ner': 5.357051246071748}
# Losses {'ner': 0.2161738376141783}
# Losses {'ner': 2.6697613586941786}
# Losses {'ner': 4.4243510989519965}
# Losses {'ner': 2.9895494053845333}
# Losses {'ner': 2.0032102879855547}
# Losses {'ner': 4.824199401384939}
# Losses {'ner': 1.355352200262048}
# Losses {'ner': 1.6719606403310272}
# Losses {'ner': 0.034545861517460155}
# Losses {'ner': 3.9556742908710154}
# Losses {'ner': 0.379858840135536}
# Losses {'ner': 1.975739516904533}
# Losses {'ner': 0.02717544117883997}
# Losses {'ner': 1.8479434689581737}
# Losses {'ner': 1.4974277023510303}
# Losses {'ner': 11.095710794334723}
# Losses {'ner': 0.04364824217775139}
# Losses {'ner': 4.1755143784812025}
# Losses {'ner': 0.16128652711032435}
# Losses {'ner': 1.7189883316488712}
# Losses {'ner': 1.6007393928689682}
# Losses {'ner': 2.335686736011601}
# Losses {'ner': 0.024870602996770644}
# Losses {'ner': 5.629396734670985}
# Losses {'ner': 3.6409682548079743}
# Losses {'ner': 0.335573649161488}
# Losses {'ner': 1.710399047225371}
# Losses {'ner': 1.1102130785253481}
# Losses {'ner': 0.0074072876146563755}
# Losses {'ner': 0.5225823338611059}
# Losses {'ner': 2.108447980328042}
# Losses {'ner': 0.9637221665276681}
# Losses {'ner': 3.9108376907683846}
# Losses {'ner': 0.3119297079843989}
# Losses {'ner': 4.225464483638974}
# Losses {'ner': 2.275207217906019}
# Losses {'ner': 0.9122852399700374}
# Losses {'ner': 1.6936988795701113}
# Losses {'ner': 0.03976950000197906}
# Losses {'ner': 0.3934724274300174}
# Losses {'ner': 4.103381237575155}
# Losses {'ner': 0.9297294478203166}
# Losses {'ner': 0.1723464735347482}
# Losses {'ner': 3.1798532134369926}
# Losses {'ner': 0.007582176313150338}
# Losses {'ner': 10.192637421118759}
# Losses {'ner': 0.03907678183444175}
# Losses {'ner': 0.6324945569081204}
# Losses {'ner': 0.20913308649646703}
# Losses {'ner': 3.6518165896422308}
# Losses {'ner': 0.3850631935910155}
# Losses {'ner': 2.1036767097633726}
# Losses {'ner': 2.1569133706357535}
# Losses {'ner': 0.5827495603161622}
# Losses {'ner': 0.24501696898523592}
# Losses {'ner': 2.845358119083041}
# Losses {'ner': 0.8278573060889066}
# Losses {'ner': 0.0519369540254438}
# Losses {'ner': 4.735703286555656}
# Losses {'ner': 3.9945967949904744}
# Losses {'ner': 0.0015494355016121746}
# Losses {'ner': 2.206426063086614}
# Losses {'ner': 0.0005006158729366429}
# Losses {'ner': 1.3264656314031404}
# Losses {'ner': 0.10909273870458128}
# Losses {'ner': 4.930046293426443}
# Losses {'ner': 0.03951470165355171}
# Losses {'ner': 4.412363174791768}
# Losses {'ner': 0.006883701909593927}
# Losses {'ner': 2.069465795727763}
# Losses {'ner': 1.7283253497681608}
# Losses {'ner': 0.20258062277974107}
# Losses {'ner': 0.0010318375215381962}
# Losses {'ner': 2.250338249278537}
# Losses {'ner': 4.332059530465058}
# Losses {'ner': 0.048092341303101825}
# Losses {'ner': 1.8563637194607967}
# Losses {'ner': 3.7359971312464277}
# Losses {'ner': 4.8066514638270445e-06}
# Losses {'ner': 0.0014282313559064942}
# Losses {'ner': 0.02822667498126084}
# Losses {'ner': 1.0900218440601959}
# Losses {'ner': 2.7417898514458368}
# Losses {'ner': 0.03563187171350203}
# Losses {'ner': 1.7177636505394815}
# Losses {'ner': 1.745660903491996}
# Losses {'ner': 1.7592016089782823}
# Losses {'ner': 2.8669084583560607}
# Losses {'ner': 0.381342673873969}
# Losses {'ner': 0.00023119517253242678}
# Losses {'ner': 1.9688580524630626}
# Losses {'ner': 0.8882328197149152}
# Losses {'ner': 0.25963927599460235}
# Losses {'ner': 2.78195926528164}
# Losses {'ner': 1.46918468449531}
# Losses {'ner': 12.318338656196094}
# Losses {'ner': 4.805522716608599e-05}
# Losses {'ner': 0.14612899028877038}
# Losses {'ner': 0.4092579588993973}
# Losses {'ner': 3.0278975164927653}
# Losses {'ner': 0.04249020375315729}
# Losses {'ner': 3.063562926971509}
# Losses {'ner': 1.4646610186172435}
# Losses {'ner': 1.2441429200308953}
# Losses {'ner': 1.8266802497640466}
# Losses {'ner': 4.292377731911474}
# Losses {'ner': 1.7768996023893797}
# Losses {'ner': 1.9161097135584613}
# Losses {'ner': 2.6733781844662534}
# Losses {'ner': 1.6271123851213833}
# Losses {'ner': 0.0005984766866655426}
# Losses {'ner': 0.2714520848855914}
# Losses {'ner': 0.0004493236590970358}
# Losses {'ner': 2.070110467987987}
# Losses {'ner': 0.004983938533281152}
# Losses {'ner': 7.114163856136431}
# Losses {'ner': 0.00040938114740998467}
# Losses {'ner': 3.6678325122106714}
# Losses {'ner': 0.0020464684778488994}
# Losses {'ner': 1.9637106649667648}
# Losses {'ner': 2.531629906592412}
# Losses {'ner': 0.7790754378428091}
# Losses {'ner': 0.002639553140423524}
# Losses {'ner': 5.667819480379316}
# Losses {'ner': 3.756842237043388}
# Losses {'ner': 0.019637498228232467}
# Losses {'ner': 1.9179316960976525}
# Losses {'ner': 3.8632123192275456}
# Losses {'ner': 0.004514307418357275}
# Losses {'ner': 0.0001777653355748693}
# Losses {'ner': 0.3950254381289582}
# Losses {'ner': 0.45989062296064964}
# Losses {'ner': 2.063692785804741}
# Losses {'ner': 0.5365418843964098}
# Losses {'ner': 1.915553144274197}
# Losses {'ner': 4.144355003181829}
# Losses {'ner': 3.826198993755069}
# Losses {'ner': 0.7291598074779508}
# Losses {'ner': 0.42427121267642603}
# Losses {'ner': 0.014723477105230831}
# Losses {'ner': 2.4452777914807937}
# Losses {'ner': 2.2008762304748584}
# Losses {'ner': 0.2624160540889446}
# Losses {'ner': 0.19262372443910725}
# Losses {'ner': 2.384093414881218}
# Losses {'ner': 12.187894900411218}
# Losses {'ner': 0.0002701857059006496}
# Losses {'ner': 0.13260748096878244}
# Losses {'ner': 0.0004780897817964489}
# Losses {'ner': 2.1884440112274497}
# Losses {'ner': 1.8541003640431108}
# Losses {'ner': 1.6173698757371662}
# Losses {'ner': 0.2831462367398207}
# Losses {'ner': 0.00718377286192882}
# Losses {'ner': 2.0058257650440248}
# Losses {'ner': 0.3249284268181462}
# Losses {'ner': 4.0761218321770025}
# Losses {'ner': 1.3615184566254712}
# Losses {'ner': 0.5669381580303224}
# Losses {'ner': 0.863532273655456}
# Losses {'ner': 1.1088249203860778}
# Losses {'ner': 0.2529959493041253}
# Losses {'ner': 0.0006318288610006391}
# Losses {'ner': 1.6473267689077025}
# Losses {'ner': 0.029776526837907193}
# Losses {'ner': 4.087565980296737}
# Losses {'ner': 0.0034920663373102833}
# Losses {'ner': 6.414672930694084}
# Losses {'ner': 0.37775693605393623}
# Losses {'ner': 1.5325063873251588}
# Losses {'ner': 0.9013245110606862}
# Losses {'ner': 1.3175012259425751}
# Losses {'ner': 0.28123075688710103}
# Losses {'ner': 5.288659372231648}
# Losses {'ner': 2.399214258659527}
# Losses {'ner': 0.00029012309178344894}
# Losses {'ner': 1.652386823259509}
# Losses {'ner': 3.215642744567245}
# Losses {'ner': 8.366885959447885e-05}
# Losses {'ner': 0.036220572844091505}
# Losses {'ner': 0.18451003817177364}
# Losses {'ner': 1.638484028141138}
# Losses {'ner': 1.6543790889319285}
# Losses {'ner': 0.797399364110713}
# Losses {'ner': 0.5198531417422804}
# Losses {'ner': 4.7499066342750345}
# Losses {'ner': 1.8208942726439845}
# Losses {'ner': 2.0033344714941843}
# Losses {'ner': 0.2540755237936909}
# Losses {'ner': 0.00028287720133127404}
# Losses {'ner': 2.0621756918129734}
# Losses {'ner': 1.3599364787800055}
# Losses {'ner': 0.5451708628216743}
# Losses {'ner': 1.6288038291546165}
# Losses {'ner': 0.12198397041929517}
# Losses {'ner': 11.931694342035938}
# Losses {'ner': 0.0001988610642987549}
# Losses {'ner': 0.024174306210442854}
# Losses {'ner': 0.0041148415329062835}
# Losses {'ner': 4.576974028363959}
# Losses {'ner': 0.004749863060468701}
# Losses {'ner': 2.7252020797590286}
# Losses {'ner': 1.2013102761654524}
# Losses {'ner': 1.8902666402300476}
# Losses {'ner': 0.8653328971263834}
# Losses {'ner': 4.830653551077174}
# Losses {'ner': 1.166334722329699}
# Losses {'ner': 2.4267169095629626}
# Losses {'ner': 2.2548117414590374}
# Losses {'ner': 1.4431615512613778}
# Losses {'ner': 0.09826698685240912}
# Losses {'ner': 0.0424818877578442}
# Losses {'ner': 0.010255309356120453}
# Losses {'ner': 0.9747200253469667}
# Losses {'ner': 0.001939166574445046}
# Losses {'ner': 4.6015547062968984}
# Losses {'ner': 0.002134161255648676}
# Losses {'ner': 5.060474270417172}
# Losses {'ner': 0.0010799216293289704}
# Losses {'ner': 1.8626131249165563}
# Losses {'ner': 1.981723137897494}
# Losses {'ner': 1.9095846112291943}
# Losses {'ner': 0.0042656367450757725}
# Losses {'ner': 5.474952090734812}
# Losses {'ner': 4.276471897361383}
# Losses {'ner': 0.353983382526746}
# Losses {'ner': 3.223731736705434}
# Losses {'ner': 1.8055328328670903}
# Losses {'ner': 2.528579698541731e-05}
# Losses {'ner': 0.008354706523124965}
# Losses {'ner': 0.1251484674685319}
# Losses {'ner': 3.6626728694642114}
# Losses {'ner': 3.9357183291097013}
# Losses {'ner': 1.5238534699619624}
# Losses {'ner': 0.09810008553903571}
# Losses {'ner': 4.8515702548206745}
# Losses {'ner': 0.42056414788577384}
# Losses {'ner': 2.0921074685025505}
# Losses {'ner': 0.710932233475864}
# Losses {'ner': 0.0017084407989778245}
# Losses {'ner': 1.1739751235093294}
# Losses {'ner': 0.17263491305444964}
# Losses {'ner': 0.01505476798938369}
# Losses {'ner': 2.3361645214271967}
# Losses {'ner': 0.020251715536681043}
# Losses {'ner': 11.973806063052756}
# Losses {'ner': 0.00011106928597435931}
# Losses {'ner': 0.7628159800574267}
# Losses {'ner': 0.43133641187014704}
# Losses {'ner': 4.368365338273924}
# Losses {'ner': 1.1604057399982939}
# Losses {'ner': 1.5186476937391022}
# Losses {'ner': 0.2934356752666577}
# Losses {'ner': 0.001588892835595475}
# Losses {'ner': 0.021421302193942608}
# Losses {'ner': 0.377690411163216}
# Losses {'ner': 0.28051294847783426}
# Losses {'ner': 1.5697561639847022}
# Losses {'ner': 1.059382100754137}
# Losses {'ner': 0.14430953620509923}
# Losses {'ner': 4.461699399821577e-05}
# Losses {'ner': 0.2014177240044398}
# Losses {'ner': 2.041987835450908e-05}
# Losses {'ner': 0.7401462831137696}
# Losses {'ner': 0.00022852978596405677}
# Losses {'ner': 5.219837157334155}
# Losses {'ner': 0.011965298740245475}
# Losses {'ner': 2.3611215206342315}
# Losses {'ner': 0.0007971243639731158}
# Losses {'ner': 2.08614327275082}
# Losses {'ner': 2.247293259943623}
# Losses {'ner': 1.1346529532627583}
# Losses {'ner': 1.9653753601662027}
# Losses {'ner': 3.551083735507425}
# Losses {'ner': 4.794168073498652}
# Losses {'ner': 0.00246444367318864}
# Losses {'ner': 1.8630163240710174}
# Losses {'ner': 4.025103167665795}
# Losses {'ner': 0.00033314857812184636}
# Losses {'ner': 1.1403898503104327e-05}
# Losses {'ner': 1.8185844191908198}
# Losses {'ner': 1.4115826132825915}
# Losses {'ner': 2.5611503976359726}
# Losses {'ner': 0.611539997466639}
# Losses {'ner': 2.0058022545077128}
# Losses {'ner': 1.2855905017470464}
# Losses {'ner': 3.206933859584197}
# Losses {'ner': 4.667695169271694}
# Losses {'ner': 0.43820410334422294}
# Losses {'ner': 2.2997773985722668e-05}
# Losses {'ner': 2.2265593853869468}
# Losses {'ner': 0.08181707569337439}
# Losses {'ner': 0.008767864693019455}
# Losses {'ner': 0.7943515265133779}
# Losses {'ner': 0.03454993642128541}
# Losses {'ner': 17.447504571461753}
# Losses {'ner': 4.867955301749123e-05}
# Losses {'ner': 0.007830438627505553}
# Losses {'ner': 0.0011477953406890307}
# Losses {'ner': 4.879527169587873}
# Losses {'ner': 0.5255368242994988}
# Losses {'ner': 3.693667858991918}
# Losses {'ner': 0.8704045386286416}
# Losses {'ner': 0.629227638891405}
# Losses {'ner': 0.009559284023051725}
# Losses {'ner': 0.1763482920794037}
# Losses {'ner': 1.7872825048973087}
# Losses {'ner': 1.9956412159873833}
# Losses {'ner': 5.667436224475846}
# Losses {'ner': 0.2456049314548946}
# Losses {'ner': 5.6830729530476776e-05}
# Losses {'ner': 0.006691637613787982}
# Losses {'ner': 1.3485246730626277e-05}
# Losses {'ner': 0.00156579652628917}
# Losses {'ner': 0.0032648680987995876}
# Losses {'ner': 1.3775021979064548}
# Losses {'ner': 0.0035421129678890263}
# Losses {'ner': 5.524384660251291}
# Losses {'ner': 0.0003316628084745844}
# Losses {'ner': 2.1324667869281457}
# Losses {'ner': 1.0212651154149972}
# Losses {'ner': 0.024363497995822006}
# Losses {'ner': 0.009913294135539211}
# Losses {'ner': 3.3451699514472883}
# Losses {'ner': 2.98676095592144}
# Losses {'ner': 0.3699591699744588}
# Losses {'ner': 1.761685781700384}
# Losses {'ner': 0.823334324413072}
# Losses {'ner': 0.0020295366306612205}
# Losses {'ner': 0.1163463724766636}
# Losses {'ner': 1.9149748525081234}
# Losses {'ner': 1.408482414967813}
# Losses {'ner': 0.862469418735183}
# Losses {'ner': 1.4648803484183948}
# Losses {'ner': 1.996276473197369}
# Losses {'ner': 5.962200786326821}
# Losses {'ner': 0.8497049012911218}
# Losses {'ner': 6.508878081643278}
# Losses {'ner': 2.466030787740643}
# Losses {'ner': 2.851608351770353e-05}
# Losses {'ner': 3.847551033943126}
# Losses {'ner': 1.2275072293614513}
# Losses {'ner': 0.004167896668882434}
# Losses {'ner': 2.5191217429370143}
# Losses {'ner': 0.0008398804400551521}
# Losses {'ner': 10.527365578534713}
# Losses {'ner': 0.007168938778545533}
# Losses {'ner': 0.14246044156806964}
# Losses {'ner': 0.006765387456239792}
# Losses {'ner': 1.7807579291027646}
# Losses {'ner': 0.06065606590530183}
# Losses {'ner': 2.507144022094028}
# Losses {'ner': 0.3840241287388053}
# Losses {'ner': 0.2969992502106825}
# Losses {'ner': 2.0856564820008763}
# Losses {'ner': 0.010114881150989064}
# Losses {'ner': 0.04152309541288842}
# Losses {'ner': 1.7614614126781216}
# Losses {'ner': 3.981520294422732}
# Losses {'ner': 1.0062326345753443}
# Losses {'ner': 1.6317984889129014}
# Losses {'ner': 0.5265547177199645}
# Losses {'ner': 5.573727121508429e-07}
# Losses {'ner': 0.05273481318787372}
# Losses {'ner': 0.006026382172200294}
# Losses {'ner': 2.60853550473823}
# Losses {'ner': 0.0005092214188538062}
# Losses {'ner': 4.903120801459655}
# Losses {'ner': 2.0209143981843533e-06}
# Losses {'ner': 1.5634685322629613}
# Losses {'ner': 0.2794981976249536}
# Losses {'ner': 0.13124469793559748}
# Losses {'ner': 0.0019988737235698386}
# Losses {'ner': 2.5265623413628466}
# Losses {'ner': 3.314177176690664}
# Losses {'ner': 0.006954298554439198}
# Losses {'ner': 2.4422549074881306}
# Losses {'ner': 2.09987755407196}
# Losses {'ner': 1.3690575515936939e-05}
# Losses {'ner': 0.00011497665168763873}
# Losses {'ner': 0.0061853264087625235}
# Losses {'ner': 0.013158191772089238}
# Losses {'ner': 1.3257550382033079}
# Losses {'ner': 0.0017192555890371394}
# Losses {'ner': 0.4205594115765628}
# Losses {'ner': 3.830331923781582}
# Losses {'ner': 0.010042632455828404}
# Losses {'ner': 7.086283156846864}
# Losses {'ner': 0.9642334855502049}
# Losses {'ner': 0.0002940823336354422}
# Losses {'ner': 2.177266403387725}
# Losses {'ner': 0.00351760528966212}
# Losses {'ner': 5.0686767291337586e-05}
# Losses {'ner': 0.005739778030819908}
# Losses {'ner': 0.2048590840880882}
# Losses {'ner': 9.712738368446018}
# Losses {'ner': 1.1110065741008477e-06}
# Losses {'ner': 1.732553081565519}
# Losses {'ner': 0.00014133400589568621}
# Losses {'ner': 1.9127511981665783}
# Losses {'ner': 6.0477552451631995}
# Losses {'ner': 1.831301790344388}
# Losses {'ner': 0.030167023418408573}
# Losses {'ner': 0.0003833541361516835}
# Losses {'ner': 0.9815482055294268}
# Losses {'ner': 0.2516415873348444}
# Losses {'ner': 0.00022652613477829294}
# Losses {'ner': 1.9157137699520463}
# Losses {'ner': 0.38699018271035324}
# Losses {'ner': 1.4723976549753137}
# Losses {'ner': 2.5787018221625508e-05}
# Losses {'ner': 0.00207684939418357}
# Losses {'ner': 0.0004528806174966161}
# Losses {'ner': 0.4489477377432045}
# Losses {'ner': 2.4413882448702486e-06}
# Losses {'ner': 4.024267171353296}
# Losses {'ner': 6.165736400201143e-05}
# Losses {'ner': 4.130830280847089}
# Losses {'ner': 0.5215859875440001}
# Losses {'ner': 0.027540576908853143}
# Losses {'ner': 1.9504053182738774}
# Losses {'ner': 0.000985292403140714}
# Losses {'ner': 0.004936081324889437}
# Losses {'ner': 2.1982852150585708}
# Losses {'ner': 3.146185614716761}
# Losses {'ner': 1.0609437238497044}
# Losses {'ner': 0.40217789543560506}
# Losses {'ner': 1.0101788521116324}
# Losses {'ner': 0.0018041454283580713}
# Losses {'ner': 0.5885466034602876}
# Losses {'ner': 1.0066658660662648}
# Losses {'ner': 3.398495579047296}
# Losses {'ner': 0.3598715399719528}
# Losses {'ner': 0.2737179689911821}
# Losses {'ner': 0.26780287852203255}
# Losses {'ner': 5.743455767154045}
# Losses {'ner': 1.976771375804443}
# Losses {'ner': 4.832014239498814}
# Losses {'ner': 0.7671148749112051}
# Losses {'ner': 0.00038549128127790826}
# Losses {'ner': 1.9886214455203863}
# Losses {'ner': 1.1386465268802328}
# Losses {'ner': 0.002014433841340063}
# Losses {'ner': 0.011210516897652583}
# Losses {'ner': 0.055271366601363774}
# Losses {'ner': 15.80826863008672}
# Losses {'ner': 0.02202199743483853}
# Losses {'ner': 0.00017334156859757287}
# Losses {'ner': 9.302020608889705e-06}
# Losses {'ner': 4.312176177069733}
# Losses {'ner': 1.4293419383452197}
# Losses {'ner': 0.10561027659442061}
# Losses {'ner': 0.004564707544576438}
# Losses {'ner': 0.11408023616752508}
# Losses {'ner': 1.7049630963460272}
# Losses {'ner': 1.790724572439183}
# Losses {'ner': 0.0004420435774684569}
# Losses {'ner': 0.007542432763217885}
# Losses {'ner': 1.5332172836874718}
# Losses {'ner': 0.4271679818024155}
# Losses {'ner': 4.775821424278987e-05}
# Losses {'ner': 1.907588317099717}
# Losses {'ner': 4.791127587026446e-07}
# Losses {'ner': 0.01516674467095273}
# Losses {'ner': 0.0076205066954165785}
# Losses {'ner': 3.8357240345230714}
# Losses {'ner': 0.0017033536299130142}
# Losses {'ner': 5.100931227364449}
# Losses {'ner': 0.024063329701757834}
# Losses {'ner': 2.451171354532949}
# Losses {'ner': 1.4373758448482652}
# Losses {'ner': 0.004211133928485034}
# Losses {'ner': 0.004805317695314008}
# Losses {'ner': 3.4428236971686346}
# Losses {'ner': 3.1155853113601992}
# Losses {'ner': 0.0120496275604719}
# Losses {'ner': 2.9697863272382587}
# Losses {'ner': 1.6111662270202238}
# Losses {'ner': 0.07837080019932363}
# Losses {'ner': 9.690795447747483e-06}
# Losses {'ner': 1.1398235514079564}
# Losses {'ner': 0.32213967758802714}
# Losses {'ner': 1.4138039692405056}
# Losses {'ner': 0.0013663220857927651}
# Losses {'ner': 0.003008628309448068}
# Losses {'ner': 3.593479641356835}
# Losses {'ner': 0.12609201134695802}
# Losses {'ner': 1.2007244262275578}
# Losses {'ner': 0.046555559312139456}
# Losses {'ner': 0.009290963719649483}
# Losses {'ner': 5.855868969559683}
# Losses {'ner': 0.00011584128523308424}
# Losses {'ner': 0.00010216845968659623}
# Losses {'ner': 1.5132959731345845}
# Losses {'ner': 0.0005005058937779359}
# Losses {'ner': 11.616254653631582}
# Losses {'ner': 1.3132330083540808e-06}
# Losses {'ner': 0.8957128991616807}
# Losses {'ner': 4.338252304230044e-06}
# Losses {'ner': 3.418369186361953}
# Losses {'ner': 0.45541309417703096}
# Losses {'ner': 1.0479823696833537}
# Losses {'ner': 0.15553106526424196}
# Losses {'ner': 3.8368094245385502}
# Losses {'ner': 0.012340622246686306}
# Losses {'ner': 3.4577055183659624}
# Losses {'ner': 0.0009944020462299152}
# Losses {'ner': 0.4409847947480148}
# Losses {'ner': 1.387249390263686e-05}
# Losses {'ner': 1.0157266031225494}
# Losses {'ner': 0.04752628494512631}
# Losses {'ner': 0.00024168105303468216}
# Losses {'ner': 3.0711349411653367e-06}
# Losses {'ner': 0.022029341311764747}
# Losses {'ner': 1.9109486957493844e-07}
# Losses {'ner': 4.6555709529943385}
# Losses {'ner': 1.7010801253581863e-05}
# Losses {'ner': 5.683609974203171}
# Losses {'ner': 0.0029635499165617304}
# Losses {'ner': 2.9073164850472555}
# Losses {'ner': 1.9969450589206181}
# Losses {'ner': 1.3519226831519586}
# Losses {'ner': 0.002901636195372207}
# Losses {'ner': 2.909213619079092}
# Losses {'ner': 1.9908999508714853}
# Losses {'ner': 0.0007753099425670067}
# Losses {'ner': 1.3014203488989258}
# Losses {'ner': 3.0825897832149707}
# Losses {'ner': 5.084153051882466e-05}
# Losses {'ner': 0.05006451706652662}
# Losses {'ner': 1.8560305356842224}
# Losses {'ner': 0.004330845454445703}
# Losses {'ner': 0.012983129951732638}
# Losses {'ner': 1.453475303208812}
# Losses {'ner': 0.04377107157633277}
# Losses {'ner': 3.927077591119049}
# Losses {'ner': 0.061959747276807774}
# Losses {'ner': 1.68005732910527}
# Losses {'ner': 0.600242516820028}
# Losses {'ner': 0.001367596655891338}
# Losses {'ner': 2.3372447681274036}
# Losses {'ner': 0.0688835066244358}
# Losses {'ner': 1.3442709512254536}
# Losses {'ner': 0.48214886266552237}
# Losses {'ner': 0.39988478745596684}
# Losses {'ner': 12.302485455805742}
# Losses {'ner': 2.3410365058169794e-05}
# Losses {'ner': 6.029144117842498e-05}
# Losses {'ner': 0.06653767316633352}
# Losses {'ner': 5.06730317639151}
# Losses {'ner': 0.7346890531220939}
# Losses {'ner': 1.9492735311852651}
# Losses {'ner': 0.8897929240978492}
# Losses {'ner': 0.005555678503347842}
# Losses {'ner': 1.9035829814833063}
# Losses {'ner': 1.7543535467993927}
# Losses {'ner': 0.008782379586136346}
# Losses {'ner': 1.605175823800039}
# Losses {'ner': 0.8602760752862997}
# Losses {'ner': 0.0045817684602002424}
# Losses {'ner': 2.3629311703482466e-06}
# Losses {'ner': 0.00022143195954870342}
# Losses {'ner': 0.0007191117948384884}
# Losses {'ner': 0.0005111022253409848}
# Losses {'ner': 1.3724013656253978e-05}
# Losses {'ner': 4.947956431531233}
# Losses {'ner': 7.840197139493579e-05}
# Losses {'ner': 6.498851920640455}
# Losses {'ner': 0.15843541570934486}
# Losses {'ner': 1.4638106159611548}
# Losses {'ner': 2.019811293408533}
# Losses {'ner': 1.0495057692956407}
# Losses {'ner': 0.026830042871986225}
# Losses {'ner': 1.2377835980111138}
# Losses {'ner': 4.481862321480886}
# Losses {'ner': 0.023313952604254607}
# Losses {'ner': 2.147166379786253}
# Losses {'ner': 1.761354507383655}
# Losses {'ner': 0.002053428553104244}
# Losses {'ner': 4.492699634296202e-06}
# Losses {'ner': 0.05750738310953597}
# Losses {'ner': 0.2452288968903065}
# Losses {'ner': 1.341949724160874}
# Losses {'ner': 0.18491604435732353}
# Losses {'ner': 0.7834125532376139}
# Losses {'ner': 2.985755504293001}
# Losses {'ner': 1.182075582875291}
# Losses {'ner': 2.7713741436150134}
# Losses {'ner': 0.0026542916303848437}
# Losses {'ner': 5.0120106271870753e-05}
# Losses {'ner': 1.0452420078054159}
# Losses {'ner': 4.8205636583217465e-05}
# Losses {'ner': 0.05337350993309994}
# Losses {'ner': 0.003123605226149649}
# Losses {'ner': 0.05233228108344117}
# Losses {'ner': 11.80518567705046}
# Losses {'ner': 2.5182375284118945e-08}
# Losses {'ner': 0.0004257172375394389}
# Losses {'ner': 3.6739582427423884e-07}
# Losses {'ner': 3.945958237471849}
# Losses {'ner': 0.00040670940528482415}
# Losses {'ner': 0.04233613806902923}
# Losses {'ner': 0.19994252313870495}
# Losses {'ner': 0.11158498239779846}
# Losses {'ner': 1.7313790379082261}
# Losses {'ner': 0.9255250687463558}
# Losses {'ner': 0.09178981679873872}
# Losses {'ner': 0.005001889674317561}
# Losses {'ner': 0.022029454006333302}
# Losses {'ner': 1.8342643418698348}
# Losses {'ner': 0.00020314468909700615}
# Losses {'ner': 0.008523567294076198}
# Losses {'ner': 5.97939624938438e-05}
# Losses {'ner': 0.0007707792593088054}
# Losses {'ner': 4.179767808036226e-05}
# Losses {'ner': 4.1341655498279355}
# Losses {'ner': 0.0012835703519533483}
# Losses {'ner': 3.763007428143286}
# Losses {'ner': 0.00042605526993435227}
# Losses {'ner': 2.0077416330449696}
# Losses {'ner': 0.1149721659603905}
# Losses {'ner': 0.006296511293975936}
# Losses {'ner': 1.3977666092317835}
# Losses {'ner': 2.2941971541550386}
# Losses {'ner': 4.562369376905523}
# Losses {'ner': 0.022700796470127224}
# Losses {'ner': 2.195632684484986}
# Losses {'ner': 0.4998357508383427}
# Losses {'ner': 3.170121547821826e-05}
# Losses {'ner': 2.212013307275062e-05}
# Losses {'ner': 0.3591880794372927}
# ...
# Losses {'ner': 7.325996737163806e-07}
# Losses {'ner': 3.768297974752364}
# Losses {'ner': 0.5599009844520489}
# Losses {'ner': 6.072072403388593}
# Losses {'ner': 7.2014426743084875e-06}
# Losses {'ner': 4.234258158890101}
# Losses {'ner': 0.21313352864231133}
# Losses {'ner': 0.00011293869138899323}
# Losses {'ner': 0.00025937520208954166}
# Losses {'ner': 1.2264250675630117}
# Losses {'ner': 1.7040346662797725}
# Losses {'ner': 1.3781785039697322e-07}
# Losses {'ner': 0.5961691380402887}
# Losses {'ner': 0.20559405418357898}
# Losses {'ner': 1.9526507896270892e-07}
# Losses {'ner': 0.0003720558328182749}
# Losses {'ner': 1.6653239889222458}
# Losses {'ner': 0.004182436018990568}
# Losses {'ner': 0.00024811851836890317}
# Losses {'ner': 5.350826999609413e-05}
# Losses {'ner': 1.6444489134594844}
# Losses {'ner': 0.7600241707719875}
# Losses {'ner': 0.000626675183685341}
# Losses {'ner': 1.8666491120111688}
# Losses {'ner': 3.1111070496185736e-06}
# Losses {'ner': 5.177139493643526e-06}
# Losses {'ner': 0.1347299078385668}
# Losses {'ner': 0.0012406591313042117}
# Losses {'ner': 0.00022104407073484037}
# Losses {'ner': 0.19893334436860405}
# Losses {'ner': 0.009434111311107836}
# Losses {'ner': 13.889968505869676}
# Losses {'ner': 4.243316784586215e-08}
# Losses {'ner': 1.1131908985589704e-07}
# Losses {'ner': 1.9578301967639378e-05}
# Losses {'ner': 2.7207703595624646}
# Losses {'ner': 0.022129244270989886}
# Losses {'ner': 2.3308523651122695}
# Losses {'ner': 0.014197532107524797}
# Losses {'ner': 0.06522159819434602}
# Losses {'ner': 0.0030273908212777615}
# Losses {'ner': 0.02831882425386738}
# Losses {'ner': 6.5904007759505205e-06}
# Losses {'ner': 2.402597299766441e-07}
# Losses {'ner': 0.3272518116703149}
# Losses {'ner': 0.004376643593807652}
# Losses {'ner': 0.137912292217528}
# Losses {'ner': 2.645689534731247e-06}
# Losses {'ner': 0.00014291259243992663}
# Losses {'ner': 7.162767527383946e-05}
# Losses {'ner': 0.0017242430977983112}
# Losses {'ner': 2.0373367706726215}
# Losses {'ner': 2.2619781305597085e-06}
# Losses {'ner': 3.520032838708019}
# Losses {'ner': 1.934999560723991e-07}
# Losses {'ner': 0.47666351116322275}
# Losses {'ner': 3.851916872414562e-07}
# Losses {'ner': 2.0661814213380563e-08}
# Losses {'ner': 4.175477570216643e-06}
# Losses {'ner': 0.039302244962044645}
# Losses {'ner': 2.222748116944134}
# Losses {'ner': 1.320210939871988}
# Losses {'ner': 0.26999731445145253}
# Losses {'ner': 5.593522280323779}
# Losses {'ner': 0.49937710504305827}
# Losses {'ner': 0.011925029128769603}
# Losses {'ner': 0.7124823898210036}
# Losses {'ner': 0.5400882441058552}
# Losses {'ner': 0.002188730307725936}
# Losses {'ner': 6.3856426369691094e-06}
# Losses {'ner': 0.32543295907022957}
# Losses {'ner': 1.7123951483045106}
# Losses {'ner': 0.005076297581484348}
# Losses {'ner': 1.7689275192835434}
# Losses {'ner': 0.00033543829186256794}
# Losses {'ner': 0.0013874699305013983}
# Losses {'ner': 2.182505606355906e-05}
# Losses {'ner': 0.0002499435665439828}
# Losses {'ner': 0.00044121547546611484}
# Losses {'ner': 2.0000006364058214}
# Losses {'ner': 0.5377976954863743}
# Losses {'ner': 10.857736150819042}
# Losses {'ner': 9.989719141629528e-08}
# Losses {'ner': 4.283980085221017e-07}
# Losses {'ner': 0.09554919509368712}
# Losses {'ner': 3.029735512414244}
# Losses {'ner': 0.24488178925081822}
# Losses {'ner': 3.015915675183503}
# Losses {'ner': 2.4478837350973568e-05}
# Losses {'ner': 0.004463685095969237}
# Losses {'ner': 0.3346267691869204}
# Losses {'ner': 0.008131050432044125}
# Losses {'ner': 5.339209224300785e-05}
# Losses {'ner': 0.006103860965675068}
# Losses {'ner': 0.0009897196569935447}
# Losses {'ner': 0.0028995584770383064}
# Losses {'ner': 1.5652702932749726e-05}
# Losses {'ner': 1.4636615610776282e-05}
# Losses {'ner': 0.00028897326430323835}
# Losses {'ner': 0.00970943023781374}
# Losses {'ner': 0.003596566181521286}
# Losses {'ner': 3.895503189700709}
# Losses {'ner': 6.126363958883427e-07}
# Losses {'ner': 3.9536688825160016}
# Losses {'ner': 0.00033000098188179955}
# Losses {'ner': 1.6296155381286277}
# Losses {'ner': 1.3626272439454585e-06}
# Losses {'ner': 2.9616269430988066e-06}
# Losses {'ner': 1.2728532836655678e-07}
# Losses {'ner': 0.0009346680902775023}
# Losses {'ner': 3.048945538796411}
# Losses {'ner': 1.485419996015302e-05}
# Losses {'ner': 0.011002818909086224}
# Losses {'ner': 1.9707491659168306}
# Losses {'ner': 5.3772636830717864e-09}
# Losses {'ner': 0.00414439746246298}
# Losses {'ner': 0.009370792396790357}
# Losses {'ner': 0.0020710011720213167}
# Losses {'ner': 1.5917017259626895e-06}
# Losses {'ner': 0.00010047629265542937}
# Losses {'ner': 0.0001801911660523074}
# Losses {'ner': 1.3142370520336524}
# Losses {'ner': 1.971532502033064}
# Losses {'ner': 1.9712539150838815}
# Losses {'ner': 7.680526668519589e-07}
# Losses {'ner': 2.7842888029237737e-06}
# Losses {'ner': 5.280287036825741e-05}
# Losses {'ner': 0.0002613122864854475}
# Losses {'ner': 4.916145006727721e-07}
# Losses {'ner': 9.173368041233605e-07}
# Losses {'ner': 9.555479385598416e-06}
# Losses {'ner': 13.120533681539014}
# Losses {'ner': 1.0054061156026632e-08}
# Losses {'ner': 1.9350270257309505}
# Losses {'ner': 5.654523645795168e-07}
# Losses {'ner': 5.241554198689858}
# Losses {'ner': 2.1527594814455697}
# Losses {'ner': 0.000641086238197851}
# Losses {'ner': 0.3989321553513346}
# Losses {'ner': 0.0002777418204981929}
# Losses {'ner': 1.0853610954611286}
# Losses {'ner': 1.218621443919943}
# Losses {'ner': 0.015141619176428348}
# Losses {'ner': 2.5009242013151334e-05}
# Losses {'ner': 5.440289112744256e-06}
# Losses {'ner': 3.9905743604946298}
# Losses {'ner': 0.005428903104095587}
# Losses {'ner': 2.9291647819403547e-06}
# Losses {'ner': 1.3763750264154842e-07}
# Losses {'ner': 1.2565342321707945e-05}
# Losses {'ner': 1.7613520880358275}
# Losses {'ner': 2.275084492504177}
# Losses {'ner': 4.3357851698500383e-07}
# Losses {'ner': 2.838910519263153}
# Losses {'ner': 3.733592683208711e-05}
# Losses {'ner': 0.85959526060506}
# Losses {'ner': 0.00021710776890390096}
# Losses {'ner': 9.198390870429028e-06}
# Losses {'ner': 0.003973574464417913}
# Losses {'ner': 2.841986948329953}
# Losses {'ner': 3.549147236140291}
# Losses {'ner': 0.0008588486030174635}
# Losses {'ner': 0.9437904363814255}
# Losses {'ner': 4.235414154330974}
# Losses {'ner': 1.3786172135671693e-08}
# Losses {'ner': 0.0008777929945987567}
# Losses {'ner': 0.03728434920190403}
# Losses {'ner': 0.009522653631258702}
# Losses {'ner': 0.15250153344798473}
# Losses {'ner': 3.984439855559152e-05}
# Losses {'ner': 0.001787810274794018}
# Losses {'ner': 0.019241466768648068}
# Losses {'ner': 0.0005799107263259309}
# Losses {'ner': 1.999116869201402}
# Losses {'ner': 0.0004225972430227973}
# Losses {'ner': 3.3041517186095327e-07}
# Losses {'ner': 5.802217937022502e-07}
# Losses {'ner': 0.002365559466365563}
# Losses {'ner': 0.0003625607399572728}
# Losses {'ner': 0.004070962137091564}
# Losses {'ner': 5.959958194304014e-07}
# Losses {'ner': 11.20123447402298}
# Losses {'ner': 1.2526972364265823e-07}
# Losses {'ner': 1.0685983060133427e-07}
# Losses {'ner': 0.0002548848621836878}
# Losses {'ner': 3.948923135476593}
# Losses {'ner': 0.0009774792118184394}
# Losses {'ner': 1.8087189576018547}
# Losses {'ner': 0.00012449347177203356}
# Losses {'ner': 4.9454213927562494e-06}
# Losses {'ner': 3.0813988422128355e-08}
# Losses {'ner': 0.02927354420658655}
# Losses {'ner': 6.4149748914612646e-06}
# Losses {'ner': 4.0595472951399826e-08}
# Losses {'ner': 1.1202890269569133e-05}
# Losses {'ner': 0.0004338608059255808}
# Losses {'ner': 1.0026217387709118e-08}
# Losses {'ner': 1.2499400134797966e-05}
# Losses {'ner': 1.7793067122007194e-09}
# Losses {'ner': 2.415271921007636e-07}
# Losses {'ner': 4.079115165836821e-08}
# Losses {'ner': 2.7646352874370512}
# Losses {'ner': 1.8797827340480826e-08}
# Losses {'ner': 1.5753163639800403}
# Losses {'ner': 0.000207849644800405}
# Losses {'ner': 0.7490246814954392}
# Losses {'ner': 5.0830687866854815e-06}
# Losses {'ner': 0.041795003601797207}
# Losses {'ner': 7.279690326128197e-06}
# Losses {'ner': 0.018792263475842872}
# Losses {'ner': 3.382585394155585}
# Losses {'ner': 1.9677895679046442}
# Losses {'ner': 1.4537293739278963}
# Losses {'ner': 2.586871467829936}
# Losses {'ner': 2.0527438859951382e-05}
# Losses {'ner': 8.110847177710932e-10}
# Losses {'ner': 5.5999983324728606e-05}
# Losses {'ner': 5.1868398131049306e-05}
# Losses {'ner': 0.017914621710769338}
# Losses {'ner': 2.7683031853771213e-05}
# Losses {'ner': 1.2030768802221599}
# Losses {'ner': 2.00989237918625}
# Losses {'ner': 0.0018047616177410536}
# Losses {'ner': 3.6451094466526452}
# Losses {'ner': 1.0531570560764585e-05}
# Losses {'ner': 0.0001930516622859147}
# Losses {'ner': 0.00178157143654822}
# Losses {'ner': 1.0041391935742783e-07}
# Losses {'ner': 4.51663521954861e-06}
# Losses {'ner': 1.6967881108070202}
# Losses {'ner': 5.280712963386108e-06}
# Losses {'ner': 11.69760743531043}
# Losses {'ner': 1.0968804620996158e-06}
# Losses {'ner': 9.789637087571352e-08}
# Losses {'ner': 1.3664676094334218e-06}
# Losses {'ner': 1.481942002362963}
# Losses {'ner': 0.0017333331243506902}
# Losses {'ner': 1.545962913621704}
# Losses {'ner': 0.3076977895681826}
# Losses {'ner': 0.004729626727327585}
# Losses {'ner': 2.2158666820271037e-06}
# Losses {'ner': 0.045379601937210176}
# Losses {'ner': 6.785365711984423e-07}
# Losses {'ner': 3.447878404147083e-07}
# Losses {'ner': 2.4912975095457742e-05}
# Losses {'ner': 0.000597391026433199}
# Losses {'ner': 2.1917016406394235e-05}
# Losses {'ner': 6.446114000772031e-08}
# Losses {'ner': 1.6851966760010483e-08}
# Losses {'ner': 0.0008184182703079153}
# Losses {'ner': 1.6201863043993515e-06}
# Losses {'ner': 1.8345240411521644}
# Losses {'ner': 8.474716203205154e-08}
# Losses {'ner': 3.3848570492248142}
# Losses {'ner': 3.336427402303519e-05}
# Losses {'ner': 1.5972452334832683}
# Losses {'ner': 6.819223027702867e-06}
# Losses {'ner': 0.0008010256082955779}
# Losses {'ner': 1.324846399965417e-06}
# Losses {'ner': 0.04649991334555556}
# Losses {'ner': 0.1346818290405043}
# Losses {'ner': 0.016720273854356368}
# Losses {'ner': 1.660200532986419}
# Losses {'ner': 2.8787899427201995}
# Losses {'ner': 0.0038835439505475284}
# Losses {'ner': 7.401060368058791e-07}
# Losses {'ner': 0.027697774566557285}
# Losses {'ner': 1.6587109642750015}
# Losses {'ner': 1.7502280836647468}
# Losses {'ner': 3.103375416518272e-05}
# Losses {'ner': 0.2820920952146575}
# Losses {'ner': 1.0444297947936119}
# Losses {'ner': 0.19010133330431278}
# Losses {'ner': 1.5651681946167062}
# Losses {'ner': 0.0005369513925224396}
# Losses {'ner': 0.0015789373816292212}
# Losses {'ner': 7.043130458714631e-07}
# Losses {'ner': 2.0838011794575616e-07}
# Losses {'ner': 0.029661842828587692}
# Losses {'ner': 0.001705231626274408}
# Losses {'ner': 2.164482509813339e-05}
# Losses {'ner': 7.386414711900024}
# Losses {'ner': 1.641435956333333e-10}
# Losses {'ner': 0.011344216894850661}
# Losses {'ner': 2.7492880265974147e-08}
# Losses {'ner': 3.9743775224919182}
# Losses {'ner': 7.090085723101892e-05}
# Losses {'ner': 2.156377569149731}
# Losses {'ner': 0.0005639806205665476}
# Losses {'ner': 0.00019689934519686122}
# Losses {'ner': 0.04593447168638253}
# Losses {'ner': 0.45783921884693807}
# Losses {'ner': 6.011547275796434e-05}
# Losses {'ner': 0.0002754570962292329}
# Losses {'ner': 8.226454670780667e-05}
# Losses {'ner': 1.905071017416394}
# Losses {'ner': 7.838506946614078e-11}
# Losses {'ner': 8.166129143082848e-09}
# Losses {'ner': 2.501287565195551e-09}
# Losses {'ner': 0.0006287919915946405}
# Losses {'ner': 0.08115075674274166}
# Losses {'ner': 2.0929474822266734}
# Losses {'ner': 8.941938525116542e-05}
# Losses {'ner': 1.3674610475874525}
# Losses {'ner': 9.623242748122572e-07}
# Losses {'ner': 0.8967104234367208}
# Losses {'ner': 9.116036547030467e-05}
# Losses {'ner': 0.0008453532506721927}
# Losses {'ner': 5.850536418318893e-06}
# Losses {'ner': 2.3523726597333496}
# Losses {'ner': 2.0177886432496157}
# Losses {'ner': 0.0002391498268993258}
# Losses {'ner': 0.6087420179319656}
# Losses {'ner': 1.971277734999456}
# Losses {'ner': 8.213031683792486e-06}
# Losses {'ner': 7.18539966196444e-06}
# Losses {'ner': 1.6188818698702083}
# Losses {'ner': 1.496140811841201e-05}
# Losses {'ner': 8.772469310152176e-05}
# Losses {'ner': 3.2324929498010666e-08}
# Losses {'ner': 0.6381694319233817}
# Losses {'ner': 2.089224807069925}
# Losses {'ner': 0.3652744332602004}
# Losses {'ner': 0.15484016813723367}
# Losses {'ner': 0.9361612163159111}
# Losses {'ner': 7.119669588635112e-08}
# Losses {'ner': 0.7101111624788128}
# Losses {'ner': 0.0005069893180939841}
# Losses {'ner': 4.384210881054557e-05}
# Losses {'ner': 1.6918883026407077}
# Losses {'ner': 3.949463511044036e-06}
# Losses {'ner': 8.753963759801595}
# Losses {'ner': 0.06773491493633012}
# Losses {'ner': 3.5185665127445934e-06}
# Losses {'ner': 0.48598062514132334}
# Losses {'ner': 3.241890552716243}
# Losses {'ner': 4.505482062263128e-07}
# Losses {'ner': 1.9489366995321027}
# Losses {'ner': 0.5604364312829182}
# Losses {'ner': 0.004469993658202427}
# Losses {'ner': 0.18872676348710885}
# Losses {'ner': 0.0004419321025844973}
# Losses {'ner': 4.2542810586884825e-05}
# Losses {'ner': 0.004755702160911226}
# Losses {'ner': 0.0037798123183217206}
# Losses {'ner': 0.0013745194016857142}
# Losses {'ner': 3.1595507987605587e-06}
# Losses {'ner': 1.804336944376076e-05}
# Losses {'ner': 2.1425685379953898e-08}
# Losses {'ner': 0.08697481941072702}
# Losses {'ner': 0.02994738168398964}
# Losses {'ner': 1.8227199201702509}
# Losses {'ner': 1.3685454092567343e-07}
# Losses {'ner': 4.7046618890967835}
# Losses {'ner': 1.9595025257079817e-06}
# Losses {'ner': 1.5161776628204378}
# Losses {'ner': 3.8834275968617265e-07}
# Losses {'ner': 3.9785248791484646e-07}
# Losses {'ner': 1.4076970002786381e-05}
# Losses {'ner': 1.0573907951868522}
# Losses {'ner': 1.984554622205678}
# Losses {'ner': 0.4897711364390023}
# Losses {'ner': 0.10401798458156841}
# Losses {'ner': 1.9804223905632499}
# Losses {'ner': 9.483139517541832e-09}
# Losses {'ner': 0.001566273588536781}
# Losses {'ner': 1.068488471189036}
# Losses {'ner': 9.723417093875983e-06}
# Losses {'ner': 0.8198059205708007}
# Losses {'ner': 0.0004732279969716741}
# Losses {'ner': 0.0009485561055657127}
# Losses {'ner': 0.6692415442655953}
# Losses {'ner': 1.997064744493675}
# Losses {'ner': 0.004763524043314116}
# Losses {'ner': 0.002516103165655001}
# Losses {'ner': 1.8793861700209624e-08}
# Losses {'ner': 1.7359093680209543e-05}
# Losses {'ner': 0.00026378281214646017}
# Losses {'ner': 9.646471758985618e-06}
# Losses {'ner': 0.032507353235181974}
# Losses {'ner': 9.084400260494682e-06}
# Losses {'ner': 6.401410990132316}
# Losses {'ner': 1.0801740400887399e-08}
# Losses {'ner': 0.0072131406036913355}
# Losses {'ner': 1.1508306305775598e-07}
# Losses {'ner': 2.002797792742083}
# Losses {'ner': 0.0009860028097719445}
# Losses {'ner': 0.9191912882468052}
# Losses {'ner': 0.00024105019064343892}
# Losses {'ner': 0.0012449110466534984}
# Losses {'ner': 1.6171024799012348}
# Losses {'ner': 0.005201321033646986}
# Losses {'ner': 0.015457822046062893}
# Losses {'ner': 2.2078174521051054e-05}
# Losses {'ner': 9.050432391803637e-05}
# Losses {'ner': 0.008084252390478431}
# Losses {'ner': 1.3787827423685702e-05}
# Losses {'ner': 3.1447184292797086e-07}
# Losses {'ner': 1.7717305608776153e-09}
# Losses {'ner': 0.014948314618771639}
# Losses {'ner': 0.0028341338651656865}
# Losses {'ner': 3.305188908590802}
# Losses {'ner': 2.0467817378868475e-06}
# Losses {'ner': 0.9332621438889979}
# Losses {'ner': 2.923071302756569e-08}
# Losses {'ner': 0.8303164123950272}
# Losses {'ner': 1.6904926225508187e-08}
# Losses {'ner': 0.01472350398933625}
# Losses {'ner': 0.14372618929482178}
# Losses {'ner': 4.864518056876826e-05}
# Losses {'ner': 1.9583399592719806}
# Losses {'ner': 3.458996061565632e-06}
# Losses {'ner': 0.642668588090983}
# Losses {'ner': 1.9422508990779273}
# Losses {'ner': 1.2217996035735539e-05}
# Losses {'ner': 6.437449969011015e-06}
# Losses {'ner': 0.013449706487666498}
# Losses {'ner': 5.039046893287067e-05}
# Losses {'ner': 1.3402793471393514e-06}
# Losses {'ner': 5.527651978175071e-06}
# Losses {'ner': 1.9922642773958452}
# Losses {'ner': 0.0013761277694383134}
# Losses {'ner': 4.791587176781709e-06}
# Losses {'ner': 0.004818182254282269}
# Losses {'ner': 6.477673877247989e-08}
# Losses {'ner': 5.228476091169486e-09}
# Losses {'ner': 1.3450327444573034}
# Losses {'ner': 0.013447108366733716}
# Losses {'ner': 1.0428950202855237e-06}
# Losses {'ner': 1.8406255131338087e-05}
# Losses {'ner': 1.9793675913910085}
# Losses {'ner': 8.593589682789448}
# Losses {'ner': 2.7286538942190223e-10}

# %%
# from spacy.training import Example
from spacy.scorer import Scorer
from tqdm import tqdm
def evaluate(ner_model, examples):
    gold_list = []
    scorer = Scorer()
    for ex in tqdm(examples):
        input_ = ex[0]
        annot = ex[1]
        doc_gold_text = ner_model.make_doc(input_)
        example = Example.from_dict(doc_gold_text, annot)
        example.predicted = ner_model(input_)
        gold_list.append(example)
        
    return scorer.score(gold_list)
# example run  examples = [     ('Who is Shaka Khan?',      [(7, 17, 'PERSON')]),     ('I like London and Berlin.',      [(7, 13, 'LOC'), (18, 24, 'LOC')]) ]  ner_model = spacy.load(ner_model_path) # for spaCy's pretrained use 'en_core_web_sm' results = evaluate(ner_model, examples)

# %%
evaluate(trained_model, TEST_DATA)
# Out:
#  31%|█████████████████████████▌                                                         | 4/13 [00:00<00:01,  7.27it/s]C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\training\iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "Slick Chicks
# POULTRY & GAME SPECIALIST
# Tax Invoice..." with entities "[(661, 669, 'AccountNum'), (143, 154, 'ABN'), (645...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  7.53it/s]
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'sents_p': None,
#  'sents_r': None,
#  'sents_f': None,
#  'tag_acc': None,
#  'pos_acc': None,
#  'morph_acc': None,
#  'morph_per_feat': None,
#  'dep_uas': None,
#  'dep_las': None,
#  'dep_las_per_type': None,
#  'ents_p': 0.7878787878787878,
#  'ents_r': 0.4727272727272727,
#  'ents_f': 0.5909090909090909,
#  'ents_per_type': {'AccountName': {'p': 0.6666666666666666,
#    'r': 0.5714285714285714,
#    'f': 0.6153846153846153},
#   'ABN': {'p': 1.0, 'r': 0.7142857142857143, 'f': 0.8333333333333333},
#   'BSB': {'p': 0.7142857142857143,
#    'r': 0.45454545454545453,
#    'f': 0.5555555555555556},
#   'AccountNum': {'p': 0.5, 'r': 0.25, 'f': 0.3333333333333333},
#   'SwiftCode': {'p': 1.0, 'r': 0.3333333333333333, 'f': 0.5},
#   'BankName': {'p': 1.0, 'r': 0.4, 'f': 0.5714285714285715}},
#  'cats_score': 0.0,
#  'cats_score_desc': 'macro F',
#  'cats_micro_p': 0.0,
#  'cats_micro_r': 0.0,
#  'cats_micro_f': 0.0,
#  'cats_macro_p': 0.0,
#  'cats_macro_r': 0.0,
#  'cats_macro_f': 0.0,
#  'cats_macro_auc': 0.0,
#  'cats_f_per_type': {},
#  'cats_auc_per_type': {}}

# %%
for tdata in TEST_DATA:
    text = tdata[0]
    doc = trained_model(text)
    # print(doc)
    for ent in doc.ents:
        print(ent)
        print(type(ent))
        print(ent.text, ent.label_)
    spacy.displacy.render(doc, style="ent", jupyter=True)
# Out:
# Define Potential Pty Ltd
# <class 'spacy.tokens.span.Span'>
# Define Potential Pty Ltd AccountName
# 38 113 072 755
# <class 'spacy.tokens.span.Span'>
# 38 113 072 755 ABN
# 71 618 216 390
# <class 'spacy.tokens.span.Span'>
# 71 618 216 390 ABN
# 032 713
# <class 'spacy.tokens.span.Span'>
# 032 713 BSB
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">DEFINE : POTENTIAL</br>TAX INVOICE</br>Invoice Date</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Define Potential Pty Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
# </br>27 Feb 2022</br>PO Box 5482</br>KINGSTON ACT 2604</br>IP Australia</br>Invoice Number</br>P +61 2 6174 0869</br>IP Australia</br>INV-09820006</br>E admin@definepotential.com.au</br>PO Box 200</br>W definepotential.com.au</br>WODEN ACT 2606</br>Reference</br>AUSTRALIA</br>PO16515</br>ABN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     38 113 072 755
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>ABN</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     71 618 216 390
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Description</br>Quantity</br>Unit Price</br>GST</br>Amount AUD</br>Delivery of Building Trust and</br>Engagement</br>2.00</br>3,636.36</br>10%</br>7,272.73</br>Project administration</br>1.00</br>1,363.64</br>10%</br>1,363.64</br>Subtotal</br>8,636.37</br>Total GST 10%</br>863.63</br>Invoice Total AUD</br>9,500.00</br>Total Net Payments AUD</br>0.00</br>Amount Due AUD</br>9,500.00</br>Payment Information</br>Due Date: 03 Mar 2022</br>â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦</br>Direct Deposit Details</br>Account Name</br>Define Potential Pty Ltd</br>BSB</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     032 713
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
# </br>Account No</br>453 989</br>â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦â€¦.</br>When making payment, please include your invoice number or company name in your payment description.</br>If you would like to pay this invoice using credit card there will be a 2% surcharge applied to the total amount. Our accounts</br>team can prepare a credit card link upon request.</br>Please note Define Potential will never change its bank details without notifying you in person.</br></div></span>
# 28 864 970 579
# <class 'spacy.tokens.span.Span'>
# 28 864 970 579 ABN
# 183004
# <class 'spacy.tokens.span.Span'>
# 183004 AccountNum
# 8733
# <class 'spacy.tokens.span.Span'>
# 8733 AccountNum
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Account Enquiries:</br>Undeliverable mail address only</br>Quoc Bui</br>Credit Management</br>Australia Post</br>Telephone 1300 910 261 Fax 02 8214 6842</br>GPO Box 2137</br>Email cmgov1@auspost.com.au</br>MELBOURNE VIC 3001</br>For Pricing Statement copies, please call 1300 656 772</br>and say &quot;Pricing Statement&quot;</br>Australia Post</br>ABN
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28 864 970 579
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Tax Invoice</br>IP Australia</br>Attention: Central Purchasing Unit</br>PO Box 200</br>WODEN ACT 2606</br>Page 1 of 2</br>Date of Issue</br>03/02/2022</br>Summary</br>Account Number</br>183004</br>Tax Invoice Number</br>1011201494</br>Your last Tax Invoice</br>$8,690.85</br>Payments Received - Thank you</br>$8,690.85CR</br>Payment Due</br>05/03/2022</br>Balance</br>$0.00</br>Total Amount Due</br>$10,819.84</br>Total Supply this Period Ending 31/01/2022</br>$9,875.31</br>Surcharges</br>$0.00</br>GST</br>$944.53</br>Adjustments this Period</br>$0.00</br>GST on Adjustments</br>$0.00</br>$10,819.84</br>Total Amount Due</br>$10,819.84</br>For copies of Pricing Statements, please call 1300 656 772 and simply select Option 1. Reminder: Payments not received by the due date will attract a</br>Late Payment Fee.</br>See over for payment options</br>Australia Post</br>( POST billpayÂ®</br>Payment Slip</br>Free delivery</br>to selected</br>$499^</br>areas on orders</br>Buy in bulk</br>of 10 or more reams</br>perream</br>*</br>and save</br>Reflex</br>*734 0183004</br>Always</br>Date of Issue</br>03/02/2022</br>Reflex</br>with Reflex.</br>Account Number</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     183004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>PREMIUM PAPER</br>IP Australia</br>On sale until Sunday 27 February 2022</br>INK WISE</br>Visit auspost.com.au/reflex</br>Credit Representative</br>1A Quoc Bui</br>CARBON NEUTRAL</br>14 BOGSM | 500 SHEETS</br>or call 1800 729 382 today!</br>Reflex A4 Ultra White Copy Paper</br>44651</br>Payment Due</br>05/03/2022</br>Phone or online orders must be received by midday Friday 25 February 2022. ^Not available to dealers for resale.</br>*Free delivery in selected areas when you purchase 10 or more reams of A4 Copy Paper or 6 or more reams of A3 Copy</br>Paper. Delivery not applicable in all areas. Standard delivery conditions apply. Visit auspost.com.au/reflex for full terms</br>Total Amount Due</br>$10,819.84</br>and conditions.</br>Supply this Period Tax Invoice</br>Tax Invoice Number 1011201494</br>Page 2 of 2</br>Description</br>Quantity</br>Unit Price</br>Total Price</br>Total Price</br>(ex. GST)</br>(ex. GST)</br>(in. GST)</br>GST in Price</br>Imprint Large Charge Letters Regular</br>3736</br>2.00357</br>7,485.35</br>8,233.86</br>748.51</br>Imprint Small Charge Letters Regular</br>1792</br>0.99091</br>1,775.71</br>1,953.28</br>177.57</br>Int Economy Letters Air - Large 500g</br>17</br>10.25882</br>174.40</br>174.40</br>0.00</br>Int Economy Letters Air - Small 250g</br>88</br>2.90227</br>255.40</br>255.40</br>0.00</br>Local Pickup and Delivery Services</br>19</br>8.18158</br>155.45</br>171.00</br>15.55</br>Parcel Post Parcels (BYO up to 5kg)</br>2</br>14.50000</br>29.00</br>31.90</br>2.90</br>Total Supply</br>$9,875.31</br>$10,819.84</br>$944.53</br>Total GST free supplies this period</br>$429.80</br>Total GST exclusive supplies this period</br>$9,445.51</br>Total GST inclusive supplies this period</br>$10,390.04 (GST component is $944.53)</br>How to Pay</br>Post</br>BillPay Code:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8733
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>Pay in-store at Australia Post,</br>Billpay</br>DD</br>Payment by Direct Debit</br>Ref: 183004</br>online at auspost.com.au/postbillpay</br>Call 1300 910 261 to apply</br>by phone 13 18 16 or via AusPost app</br>S</br>Payment by EFT</br>1301013010223010120112300300222301113</br>Please quote the following details when making</br>an EFT payment (for use within Australia only)</br>Accounts Receivable Team</br>BSB: 064-787</br>Australia Post</br>Account No. 183004</br>GPO Box 2890</br>MELBOURNE VIC 3001</br></div></span>
# Wells Fargo Bank
# <class 'spacy.tokens.span.Span'>
# Wells Fargo Bank AccountName
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MuleSoftÂ®</br>Tax Invoice</br>D</br>A Salesforce Company</br>50 Fremont Street, Suite 300</br>Date</br>6/11/2021</br>San Francisco, CA 94105</br>Invoice #</br>INV-42640</br>Email: ar@mulesoft.com</br>Terms</br>Net 30</br>USA Tax ID: 94-3320693</br>Due Date</br>7/11/2021</br>ABN: 13614231432</br>PO #</br>Bill To</br>Ship To</br>IP Australia</br>IP Australia</br>47 Bowes Street, Discovery House</br>47 Bowes Street, Discovery House</br>Phillip ACT 2606</br>Phillip ACT 2606</br>Australia</br>Australia</br>Item</br>QTY</br>Units</br>Description</br>Rate</br>Amount</br>Tax</br>API Community Manager Developer</br>200</br>EA</br>Terms: (2021-07-10 to 2022-07-09)</br>219.863</br>43,972.60</br>Login</br>Platinum Subscription</br>1</br>EA</br>Terms: (2021-07-10 to 2022-07-09)</br>0.00</br>0.00</br>All software is delivered via electronic transmission.</br>OFN #: Q-121168</br>Total</br>AUD $43,972.60</br>GST</br>OpenAir Invoice Link</br>Link to Consulting Detail:</br>Late Fee: 1.5% fee per month of the amount due, unless otherwise specified in your contract.</br>To Send Payment via ACH:</br>Account #: 4122247414</br>ABA/Routing#: 121000248</br>To Wire Funds:</br>Bank:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wells Fargo Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
#  N.A.</br>Account #: 4122247414</br>Acct. Name: Mulesoft LLC.</br>SWIFT BIC Code (USD wire): WFBIUS6S</br>SWIFT BIC Code (non-USD wire): WFBIUS6WFFX</br>To Remit by Check (only US bank checks are accepted):</br>MuleSoft, Inc.</br>PO Box 398848</br>San Francisco, CA 94139-8848</br></div></span>
# 74 599 608 295
# <class 'spacy.tokens.span.Span'>
# 74 599 608 295 ABN
# Reserve Bank of Australia
# <class 'spacy.tokens.span.Span'>
# Reserve Bank of Australia BankName
# Department of Industry, Science, Energy and Resources
# <class 'spacy.tokens.span.Span'>
# Department of Industry, Science, Energy and Resources AccountName
# 092-009
# <class 'spacy.tokens.span.Span'>
# 092-009 BSB
# 118689
# <class 'spacy.tokens.span.Span'>
# 118689 AccountNum
# RSBKAU2S
# <class 'spacy.tokens.span.Span'>
# RSBKAU2S SwiftCode
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Australian Government</br>TAX INVOICE</br>Department of Industry, Science,</br>Department of Industry, Science,</br>Energy and Resources</br>Energy and Resources</br>GPO Box 2013</br>CANBERRA ACT 2601</br>ABN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     74 599 608 295
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>IP AUSTRALIA</br>Invoice No:</br>AR10001788</br>PO BOX 200</br>WODEN ACT 2606</br>Date:</br>08/02/2022</br>Debtor Id:</br>D004155</br>Due Date:</br>22/02/2022</br>Attention:</br>Manager of Accounts</br>Page :</br>1 of 1</br>Quantity and Description</br>Exclusive GST</br>GST</br>Total Amount</br>Recovery of PS invoice 27774</br>6,090.00</br>6,090.00</br>EAP January 2022</br>IP AUSTRALIA</br>Total Amount Due ($AUD):</br>$6,090.00</br>$0.00</br>$6,090.00</br>Payment Options:</br>7</br>Direct Credit:</br>+</br>By Cheque or Remittance:</br>Direct credit payments can be made to the following account:</br>Bank Name:</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reserve Bank of Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BankName</span>
# </mark>
# </br>Please detach this section and return with your</br>Bank Address:</br>20-22 London Circuit</br>Cheque, or send your Remittance to:</br>Canberra ACT Australia</br>Account Name:</br>Department of Industry, Science, Energy and</br>Resources</br>Accounts Receivable</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Department of Industry, Science, Energy and Resources
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
# </br>BSB No:</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     092-009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
# </br>GPO Box 2013, CANBERRA ACT 2601</br>Account No:</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     118689
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>Swift Code No:</br>or</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RSBKAU2S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SwiftCode</span>
# </mark>
# </br>Email: cpm@industry.gov.au</br>Please quote</br>AR10001788</br>in the reference field to enable your payment to be processed</br>Credit Card:</br>Invoice No:</br>AR10001788</br>We accept payment by credit card - Please ring (02) 6213 6145</br>Invoice Date:</br>08/02/2022</br>Debtor Id:</br>D004155</br>For enquiries please call : (02) 6213 6145</br>Amount Due ($AUD):</br>$6,090.00</br></div></span>
# C:\Users\Uridah\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\displacy\__init__.py:191: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Slick Chicks</br>POULTRY &amp; GAME SPECIALIST</br>Tax Invoice</br>4 Rogilla Close, Maryland NSW 2287</br>Phone: 49516226 ~ Fax: 49516227</br>Invoice #:</br>00660357</br>ABN: 17078782537</br>Bill To:</br>Ship To:</br>TAFE NSW</br>TAFE NSW</br>Accounts Payable - SSC</br>HVHA KURRI KURRI CAMPUS</br>GPO BOX 4037</br>BLOCK H MAIN STORE</br>Locked Bag 45</br>O/N: 7000024522 commercial cookery</br>SYDNEY NSW 2001</br>McLeod Street</br>ORDER NO:</br>TERMS</br>DATE</br>PG.</br>7000025789</br>Net 14</br>9/11/2021 Page 1 of 1</br>QTY.</br>ITEM NO.</br>DESCRIPTION</br>PRICE</br>UNIT</br>DISC %</br>EXTENDED</br>COD</br>PRICE</br>4</br>F15</br>Tenderloin Fillets</br>$9.95</br>kg</br>$39.80</br>FRE</br>10</br>CT</br>Crumbed Tenderloin FRESH</br>$9.95</br>kg</br>$99.50</br>FRE</br>34</br>K3</br>Kebabs, 1 Tenderloins SATAY</br>$1.10</br>ea</br>$37.40</br>FRE</br>BANK DETAILS: BSB-332-056 A/C NO: 553478661</br>SALE AMT.</br>$176.70</br>FREIGHT</br>$0.00</br>FRE</br>GST</br>$0.00</br>TOTAL AMT.</br>$176.70</br>PAID TODAY</br>$0.00</br>BALANCE DUE</br>$176.70</br>Mail content report generated by COLLECTOR</br>From:</br>&quot;Slick Chicks&quot;</br>Created:</br>9/11/2021 9:10 AM</br>To:</br>&quot;accountspayable@tafensw.edu.au&quot;</br>Subject:</br>[External]Invoice 00660357; From Slick Chicks Pty Ltd</br>Attachments:</br>INV00660357.pdf</br>CAUTION: This email originated from outside of TAFE NSW. Do not click links or open attachments unless you recognise the sender and know the content is safe.</br>Please contact us immediately if you are unable to detach or download your Invoice.</br>Kind Regards</br>Phone: 0249516226</br>Fax: 0249516227</br>Email: info@slickchicks.com.au</br>Webpage: www.slickchicks.com.au</br></div></span>
# ZEPP & CO
# <class 'spacy.tokens.span.Span'>
# ZEPP & CO AccountName
# Zepp & Co Pty Ltd
# <class 'spacy.tokens.span.Span'>
# Zepp & Co Pty Ltd AccountName
# 0414 259 250
# <class 'spacy.tokens.span.Span'>
# 0414 259 250 BSB
# 032-
# <class 'spacy.tokens.span.Span'>
# 032- BSB
# WPACAU2S
# <class 'spacy.tokens.span.Span'>
# WPACAU2S SwiftCode
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ZEPP &amp; CO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
# </br>PAUL PITTIONI</br>VOICE OVER</br>TAX INVOICE</br>Invoice Date</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zepp &amp; Co Pty Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
# </br>30 Nov 2021</br>129 The Comenarra</br>IAG</br>Invoice Number</br>Parkway</br>INV-04861</br>Turramurra NSW 2074</br>SYDNEY NSW 2000</br>AUSTRALIA</br>AUSRALIA</br>ABN</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0414 259 250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
# </br>72 104 433 356</br>ppittioni@bigpond.com</br>paulpittioni.com.au</br>Description</br>Quantity</br>Unit Price</br>Amount AUD</br>Paul Pittioni Voice Over Session</br>2.00</br>500.00</br>1,000.00</br>2 x 30&quot; National TVCs - 3 month duration</br>Subtotal</br>1,000.00</br>TOTAL GST 10%</br>100.00</br>TOTAL AUD</br>1,100.00</br>Due Date: 14 Dec 2021</br>Terms are 14 days</br>Payment to:</br>Bank : Westpac</br>Acc Name: Zepp &amp; Co Pty Ltd</br>BSB:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     032-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
# 090</br>Acc Number: 368-840</br>Swift Code :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WPACAU2S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SwiftCode</span>
# </mark>
# </br></div></span>
# 12 497 045 671
# <class 'spacy.tokens.span.Span'>
# 12 497 045 671 ABN
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">infinityengraving</br>Tax Invoice</br>where the possibilities are endless</br>ABN</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 497 045 671
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Date:</br>28/02/202</br>2</br>Invoice #:</br>00009592</br>To:</br>CASH SALE</br>Ship To:</br>CASH SALE</br>PURCHASE ORDER</br>SHIP VIA</br>TERMS</br>DUE DATE</br>Net 30</br>30/03/2022</br>QUANTITY</br>DESCRIPTION</br>UNIT PRICE</br>21</br>Medals</br>$16.50</br>SUB TOTAL</br>$315.00</br>ALL PAYMENTS MUST SHOW INVOICE</br>FREIGHT</br>$0.00</br>NUMBER ADDRESSING PAYMENT</br>GST</br>$31.50</br>TOTAL</br>$346.50</br>Details for Direct Debit</br>Cheque Payment</br>Account Name: Infinity Engraving</br>Please make cheques payable to</br>Account Number: 10369642</br>Infinity Engraving</br>BSB Number: 062904</br>Commonwealth Bank</br>Site Address: 59 Cossington Smith Cres Lyneham ACT 2602</br>Phone: 02 6262 9862</br>Fax: 02 6248 7274</br>Mob: 041 260 4402</br>email: james@infinityengraving.com.au www.infinityengraving.com.au</br></div></span>
# 12 080 534 005
# <class 'spacy.tokens.span.Span'>
# 12 080 534 005 ABN
# Bevington Consulting Pty Ltd
# <class 'spacy.tokens.span.Span'>
# Bevington Consulting Pty Ltd AccountName
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BEVINGTON GROUP</br>TAX INVOICE</br>PERFORMANCE OUTCOMES DELIVERED</br>XeP3</br>Tax Invoice Number: I001132</br>ABN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 080 534 005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Bevington Job Code: IPAUS02</br>Order Number: PO 17005</br>28 February 2022</br>Heath Wilson</br>IP Australia</br>47 Bowes Street</br>Phillip</br>ACT 2606</br>Australia</br>heath.wilson@ipaustralia.gov.au</br>This invoice relates to the provision of consulting services for the TM&amp;D Operations &amp; Hearings Implementation</br>Support Project at IP Australia.</br>These Consulting Services are for the period ending 28th February 2022.</br>Please note that expenses are separately billed.</br>Billing Category</br>Units (Days)</br>Cost/Day</br>Total</br>Defence Panel (Strategic Biz Advice)</br>0.5</br>$2,569.44</br>$1,284.72</br>Level 4, Managing Director</br>-</br>Defence Panel (Strategic Biz Advice)</br>6.0</br>$2,055.52</br>$12,333.12</br>Level 3, Managing Consultant</br>-</br>Total (excluding GST &amp; expenses)</br>$13,617.84</br>Fees:</br>$13,617.84</br>GST:</br>$1,361.78</br>TOTAL INVOICE:</br>$14,979.62</br>Payment Terms: 20 days</br>Please direct all queries to Roger Perry on (03) 9663 5522.</br>Payment to be forwarded to -</br>Accounts Department</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bevington Consulting Pty Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountName</span>
# </mark>
# </br>Level 4/55 Exhibition St.</br>Melbourne, Victoria 3000</br>For Electronic Payments -</br>Account Name:</br>Bevington Consulting Pty Ltd</br>BSB:</br>013 445</br>Account Number:</br>493 856 711</br>Please include the tax invoice number I001132 as a reference on electronic payments.</br>L E V E L 4 / 5 5 E X H I B I T I O N S T . â€¢ M E L B O U R N E , V I C T O R I A â€¢ 3 0 0 0 â€¢ P H O N E : 0 3 9 6 6 3 5 5 2 2</br>E M A I L :</br>A C C O U N T S @ B E V I N G T O N G R O U P . C O M</br></div></span>
# 23 063 641 510
# <class 'spacy.tokens.span.Span'>
# 23 063 641 510 ABN
# Bank of America
# <class 'spacy.tokens.span.Span'>
# Bank of America BankName
# 232 001
# <class 'spacy.tokens.span.Span'>
# 232 001 BSB
# 17159011
# <class 'spacy.tokens.span.Span'>
# 17159011 AccountNum
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dynatrace</br>Dynatrace Asia Pacific Pty. Ltd.</br>Level 18</br>TAX INVOICE</br>100 Miller St</br>North Sydney NSW 2060</br>Australia</br>INVOICE DATE: 28/02/2022</br>finance.au@dynatrace.com</br>INVOICE #: AUS-2001826</br>Telephone: 02 8875 5000</br>Fax: 02 8875 5100</br>ABN:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23 063 641 510
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>BILL TO:</br>LICENSE ADDRESS:</br>IP Australia</br>IP Australia</br>PO Box 200</br>47 BOWES ST</br>Woden ACT 2606</br>PHILLIP 2606</br>Australia</br>Australia</br>PAYMENT TERMS: NET 21</br>CUSTOMER #: 176324:1</br>PO #: 17153</br>CONTRACT #: Q-271836</br>DUE DATE: 21/03/2022</br>SALES REP: May Y Eer</br>DESCRIPTION</br>QTY</br>AMOUNT</br>Dynatrace SaaS - DEM Units - Renewal</br>2.5</br>$ 42,685.00</br>Dynatrace SaaS - Davis Data Units - Renewal</br>1.5</br>$ 5,803.50</br>Dynatrace SaaS - DEM Units - Renewal</br>1.2</br>$ 16,591.85</br>Dynatrace SaaS - Host Units - Renewal</br>67</br>$ 117,428.22</br>TAX TOTAL</br>$ 18,250.86</br>-</br>-</br>-</br>-</br>-</br>-</br>-</br>-</br>TOTAL</br>$ 200,759.43</br>TERMS CONDITIONS/COMMENTS</br>CONTRACT START DATE</br>26/2/2022</br>CONTRACT END DATE</br>25/2/2023</br>Electronically Delivered</br>Account Name: Dynatrace Asia-Pacific Pty Ltd</br>Name Of Bank:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bank of America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BankName</span>
# </mark>
# </br>Swift Code: BOFAAUSX</br>BSB:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     232 001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
# </br>Account Number:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17159011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>1 of 1</br></div></span>
# 082-057
# <class 'spacy.tokens.span.Span'>
# 082-057 BSB
# 974252919
# <class 'spacy.tokens.span.Span'>
# 974252919 AccountNum
# 97 164 598 120
# <class 'spacy.tokens.span.Span'>
# 97 164 598 120 ABN
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BECAMPBELL</br>Quality Australian Meat Family Owned Since 1969</br>Tax Invoice</br>Bill-To Customer</br>NSW TAFE South West Sydney Institute</br>Invoice No.</br>91026558</br>136 WILLIAM STREET</br>Invoice Dt.</br>08.11.2021</br>GRANVILLE NSW 2142</br>Delivery No.</br>85692697</br>PO No.</br>Created By</br>SMASON</br>Customer</br>TAFE</br>Ship-To Customer</br>Tel No.</br>96820407</br>GRAN</br>Shipment No.</br>1123185</br>GRANVILLE TAFE</br>Route</br>1920BU</br>136 WILLIAM STREET</br>GRANVILLE NSW 2142</br>Terms of Pmt</br>Net due in 28 days</br>Page</br>1 of 1</br>Standard Delivery Instructions</br>Special Delivery Instructions</br>Del off Elizabeth St. (1st gate on right)</br>P/O 7000018134</br>Material</br>Description</br>Qty Weight(kg)</br>Unit Price</br>Value(AUD)</br>320500C1</br>P^TOPSIDE DENUDED R/L B/L GC</br>6 CTN</br>82.470</br>9.00 / KG</br>742.23</br>Z1460000</br>P^SADDLE</br>1 EA</br>23.400</br>7.60 / KG</br>177.84</br>Total Quantity:</br>6 CTN</br>1 EA</br>Subtotal before GST</br>$920.07</br>Total this Invoice</br>$920.07</br>Previous Amount Owing</br>$3,246.98</br>Total Owing</br>$4,167.05</br>BE Campbell will NOT ask you to change bank account details by email, phone or by changing the details on the invoice. If you</br>-</br>receive a request to change our bank account details, please call your Sales Rep or Accounts Receivable ASAP.</br>BSB:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     082-057
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
#  ACCOUNT NO:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     974252919
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>All Claims must be notified within 24 hours of delivery. Please note that any returns must be in the original packaging.</br>T +61 2 9725 2233 E reception@becampbell.com.au W www.becampbell.com.au</br>BE Campbell Pty Ltd - 144 Newton Road, Wetherill Park NSW 2164, Australia | PO Box 7042, Wetherill Park, 2164 | ABN
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97 164 598 120
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Mail content report generated by COLLECTOR</br>From:</br>acctrec@becampbell.com.au</br>Created:</br>8/11/2021 5:38 AM</br>To:</br>accountspayable@tafensw.edu.au</br>Subject:</br>[External]BEC invoice 91026558 for GRAN</br>Attachments:</br>BEC invoice 91026558 for GRAN.pdf</br>The email is RTF formatted and COLLECTOR only supports plain text</br>format for the body.</br></div></span>
# 97 414 746 779
# <class 'spacy.tokens.span.Span'>
# 97 414 746 779 ABN
# 032-135
# <class 'spacy.tokens.span.Span'>
# 032-135 BSB
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">0 mwah.</br>making work absolutely human.</br>TAX INVOICE</br>Invoice Date</br>mwah.</br>16 Nov 2021</br>Making Work</br>Invoice Number</br>Absolutely Human</br>IAG</br>Attention: Deborah Chapman</br>INV-0529</br>Pty Ltd</br>Suite 5, 1-7 Albion</br>Tower 2, Darling Park, 201 Sussex Street,</br>SYDNEY NSW 2000</br>Reference</br>Place,</br>Workshop</br>SYDNEY NSW 2000</br>AUSTRALIA</br>ABN</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97 414 746 779
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>Description</br>Quantity</br>Unit Price</br>GST</br>Amount AUD</br>Finance Leadership Team</br>1.00</br>7,000.00</br>10%</br>7,000.00</br>Workshop Facilitation and outcomes</br>Subtotal</br>7,000.00</br>TOTAL GST 10%</br>700.00</br>TOTAL AUD</br>7,700.00</br>Due Date: 16 Dec 2021</br>Payment options:</br>EFT or Master card &amp; Visa Card (by phone)</br>Name: mwah. Making Work Absolutely Human Pty Ltd</br>BSB:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     032-135
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BSB</span>
# </mark>
#  Acc: 594 834</br>Terms 7 days</br>Contact: Michael@mwah.live 0448 710 344 / +61 (2) 9267 3079</br>mwah. is a subsidiary of The Trustee for Mwah. Unit Trust</br></div></span>
# 19 002 966 001
# <class 'spacy.tokens.span.Span'>
# 19 002 966 001 ABN
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Universal McCann</br>A division of Mediabrands Australia Pty Ltd</br>UM</br>100 Chalmers Street</br>Surry Hills, NSW, Australia 2010</br>ABN
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19 002 966 001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ABN</span>
# </mark>
# </br>+61 2 9994 4200 tel</br>+61 2 8586 2080 fax</br>TAX INVOICE/ADJUSTMENT NOTE</br>Master Client</br>Industry Science Energy &amp; Res</br>AccountingOps@ipaustralia.gov.au</br>Invoice No</br>45349</br>Client</br>IP Australia</br>[IPSAGR]</br>IP Australia</br>PO Box 200</br>Date</br>02/02/2022</br>Product</br>Trade Mark Ex Affirmative Meas</br>[0339BL]</br>Woden, ACT, 2606</br>Country</br>Australia</br>Australia</br>Page</br>Page 1 of 1</br>Purchase Order</br>Attn: Reema Shah</br>X=SIZE, S=SPOT, P=PACKGE, A=CPA, F=FIXED, K=CPC, M=CPM, %=Perc., C=Cum.Perc.</br>Date Program / Placement</br>Duration / Size</br>Reference</br>No</br>Rate and Loading(s)</br>Total</br>21RIPS0339BL</br>Digital Social LinkedIn LinkedIn Social GST 15% Comm</br>Sun-Sat</br>03/10/2021 Display</br>Premium Listing</br>0339BL / 4</br>-1</br>117.00(S)</br>-117.00</br>03/10/2021 - 03/10/2021 AQ136878</br>AQ141537</br>Ref. Inv. 43001 25/11/2021</br>Total 21RIPS0339BL</br>-117.00</br>WOAG=Whole of Australian Government Management fee is 9% of Gross Media (or 6% of Gross Media prior 4/7/21)</br>Payment due 30 days from date of receipt. Credit card options available. Citibank Sydney BSB 242-000 A/C 232874015</br>Total Cost</br>-117.00</br>Commission Rebate</br>17.55</br>WOAG Fee 9%</br>-10.53</br>Total Charges</br>-109.98</br>Goods and Services Tax</br>-11.00</br>Amount Payable</br>-120.98</br></div></span>
# 1427248
# <class 'spacy.tokens.span.Span'>
# 1427248 AccountNum
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">21/09/2021 Tue 15:34</br>Gunnebo</br>ID: #151131 Page 1 of 1</br>GUNNEBO</br>Gunnebo Australia Pty Ltd</br>Invoice Date: 21-SEP-21</br>P.O. Box 8254</br>Baulkham Hills B.C.</br>Invoice No:</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1427248
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AccountNum</span>
# </mark>
# </br>For a safer world</br>NSW 2153</br>8 &amp; 9 / 16 Lexington Drive</br>A.B.N. 43093709749</br>Ph 02 8074 9567</br>Bella Vista, NSW, 2153</br>Fax 02 9852 0731</br>ar.au@gunnebo.com</br>Bill To:</br>Deliver To:</br>Accounts Payable</br>IP Australia</br>IP AUSTRALIA</br>PO Box 200</br>IP AUSTRALIA</br>Woden</br>47 BOWES ST</br>ACT</br>PHILLIP</br>2606</br>ACT</br>TAX INVOICE</br>Total Due:</br>200.20</br>Account</br>Your Order Ref:</br>Currency:</br>Rep:</br>Call No:</br>Our Order No.</br>1000954</br>17020</br>$AUD</br>MALCOM DOYLE</br>700745</br>1841050</br>Item Code</br>Item Description</br>Qty</br>B/Ord |UOM</br>Price</br>Disc%</br>Total</br>Service Call on Unit</br>Serial # UK000565</br>Caller : Craig Caldwell</br>Call No: 700745</br>Fault Details</br>21-09-21: Issue- we require the attendance of a</br>tech urgently as the those speed stiles are</br>malfunctioning once again and causing issues with</br>access.</br>Please liaise with the IPA Duty Officer (0414 512</br>513) or security@ipaustralia.gov.au to arrange</br>access or if you have further questions.</br>Tech to attend and repair</br>Contact person- Craig Caldwell @ 61 2 6283 7937</br>WON- 17020</br>Travel distance 9.8 km each side</br>ETA shared on email for today in afternoon</br>Repair Details</br>21/9/21 On arrival, Master Side wing was unresponsive and</br>showing an &quot;out of target&quot; fault. Performed reset and</br>learning cycle on both sides and achieved normal operation.</br>Cycled 50+ times without fault. Units are ageing, 2013</br>install. 1st Generation NEP.</br>Engineer: 969</br>RSS-CONH-2416</br>Service Callout Normal Hours</br>1.00</br>0.00</br>HR</br>260.00 30.00</br>182.00</br>EFT Payements To:</br>Payment Terms: Nett 30 days</br>Ex Tax:</br>182.00</br>BNP Paribas, Sydney</br>BSB 222 200</br>(creditor) watchÂ®</br>GST:</br>18.20</br>Account 201097001</br>Swift: BNPAAU2SXXX</br>Total:</br>200.20</br>ar.au@gunnebo.com</br>member</br>No claims recognised after 7 days. Title of goods does not transfer until paid in full.</br>Terms and Conditions can be found at: http://www.gunnebo.com.au</br>Page: 1 of 1</br>true</br>700745 - STATUS = Job Completed - 21/09/2021 02:38 PM</br>true</br>GUNNEBO</br>R</br>Service Report</br>For a safer world</br>Contracted Company:</br>IP Australia</br>Job No:</br>700745</br>Client:</br>IP Australia</br>Order No:</br>17020</br>Address:</br>47 Bowes St, Phillip ACT</br>Hand Tools checked and inspected before use:</br>SITE SPECIFIC RISK ASSESSMENT</br>SERVICE CONDUCTED:</br>(To be completed before commencing work)</br>Portable Electrical Equipment Test and Tagged:</br>Service Call</br>Quotation</br>N</br>N</br>Hazards</br>P.P.E</br>Isolation</br>N</br>Access</br>N</br>Environment</br>Workshop Repair</br>Warranty</br>Control</br>Control</br>Preventative Maintenance</br>Re-Call</br>Y</br>Y</br>Y</br>Y</br>Y</br>Install/Commissioning</br>Lifting</br>Head</br>Electrical</br>Barricades</br>Silt &amp; Sediment</br>Details of service required:</br>Height</br>Eyes</br>Mechanical</br>Signage</br>Noise Pollution</br>Access</br>Ears</br>Infectious</br>Traffic Control</br>Lane #1 fault.</br>Temperature</br>Suit</br>Chemical</br>Lighting</br>Feet</br>Radiation</br>Energy Source</br>Biological</br>Stored Energy</br>Body Fluids</br>Risk Assessment completed to the best of</br>my ability</br>Falling Object</br>AFTER HOURS SERVICE (Client Approved)</br>Slip, Trip, falls</br>Signature:</br>AFTER 9PM (Client also Approved)</br>Confined Space</br>Engulfment</br>PRODUCT AREA:</br>Allergies</br>Cash Management</br>Entrance Control</br>Security (Windows, Doors &amp; Partitions)</br>Safes &amp; Vaults</br>Date:</br>21/9/2021</br>Perimeter Protection</br>Retail Store Security</br>Kms calculated as the one way distance from the CBD to the Client</br>Fault Cause:</br>Product Details:</br>Date:</br>Tech ID:</br>Arrival Time:</br>Depart Time:</br>Kms</br>X</br>Operator:</br>N</br>Version:</br>Speedstile FP NEP</br>Machine</br>Other:</br>21/9/2021< ...

# %%
create_test_train_split("../../data")

# %%
[x for x in TEST_DATA[4][1]['entities'] if x[2] == 'ABN']
# Out:
# [(239, 250, 'ABN')]

# %%
from spacy.training import Example
from spacy.scorer import Scorer

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = Example(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
        return scorer.scores  # example run  examples = [     ('Who is Shaka Khan?',      [(7, 17, 'PERSON')]),     ('I like London and Berlin.',      [(7, 13, 'LOC'), (18, 24, 'LOC')]) ]  ner_model = spacy.load(ner_model_path) # for spaCy's pretrained use 'en_core_web_sm' results = evaluate(ner_model, examples)

# %%
TEST_DATA[0][0]
# TEST_DATA[0][1]

# %%
trained_model(TEST_DATA[2][0]).ents
# Out:
# (74 599 608 295,
#  Reserve Bank of Australia,
#  Department of Industry, Science, Energy and Resources,
#  118689,
#  RSBKAU2S)

# %%
len(TEST_DATA[0])
# Out:
# 2

# %%
for i, x in enumerate(TEST_DATA[0]):
    print(i, x)
# Out:
# 0 ZEPP & CO
# PAUL PITTIONI
# VOICE OVER
# TAX INVOICE
# Invoice Date
# Zepp & Co Pty Ltd
# 30 Nov 2021
# 129 The Comenarra
# IAG
# Invoice Number
# Parkway
# INV-04861
# Turramurra NSW 2074
# SYDNEY NSW 2000
# AUSTRALIA
# AUSRALIA
# ABN
# 0414 259 250
# 72 104 433 356
# ppittioni@bigpond.com
# paulpittioni.com.au
# Description
# Quantity
# Unit Price
# Amount AUD
# Paul Pittioni Voice Over Session
# 2.00
# 500.00
# 1,000.00
# 2 x 30" National TVCs - 3 month duration
# Subtotal
# 1,000.00
# TOTAL GST 10%
# 100.00
# TOTAL AUD
# 1,100.00
# Due Date: 14 Dec 2021
# Terms are 14 days
# Payment to:
# Bank : Westpac
# Acc Name: Zepp & Co Pty Ltd
# BSB: 032-090
# Acc Number: 368-840
# Swift Code :WPACAU2S
#
# 1 {'entities': [(570, 577, 'BSB'), (610, 618, 'SwiftCode'), (529, 536, 'BankName'), (217, 231, 'ABN'), (590, 597, 'AccountNum'), (60, 77, 'AccountName')]}

# %%
type(TEST_DATA[0])
# Out:
# tuple

# %%
from spacy.tokens import Doc
from spacy.training import Example
nlp = spacy.load("en_core_web_sm")
words = ["hello", "world", "!"]
spaces = [True, False, False]
predicted = Doc(nlp.vocab, words=words, spaces=spaces)
reference = Example.reference(my_data)
example = Example(predicted, reference)
example
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17228/1169758104.py in <module>
#       5 spaces = [True, False, False]
#       6 predicted = Doc(nlp.vocab, words=words, spaces=spaces)
# ----> 7 reference = Example.reference(my_data)
#       8 example = Example(predicted, reference)
#       9 example
#
# NameError: name 'my_data' is not defined

# %%
Doc(TEST_DATA[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17228/4271966334.py in <module>
# ----> 1 Doc(TEST_DATA[0])
#
# TypeError: Argument 'vocab' has incorrect type (expected spacy.vocab.Vocab, got tuple)

# %%
ner = nlp.add_pipe("ner")
ner.initialize(lambda: [], nlp=nlp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17228/2989455817.py in <module>
# ----> 1 ner = nlp.add_pipe("ner")
#       2 ner.initialize(lambda: [], nlp=nlp)
#
# ~\OneDrive\Documents\virtual_environments\spend_console_env\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     758         name = name if name is not None else factory_name
#     759         if name in self.component_names:
# --> 760             raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     761         if source is not None:
#     762             # We're loading the component from a model. After loading the
#
# ValueError: [E007] 'ner' already exists in pipeline. Existing names: ['tok2vec', 'tagger', 'parser', 'senter', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ner.get_examples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17228/2747707516.py in <module>
# ----> 1 ner.get_examples
#
# NameError: name 'ner' is not defined

# %%
import os
# import sys
import string
import spacy

# sys.path.append('..')

from src.utils import azure_utils

# MODEL_PATH = azure_utils.download_model()
MODEL_PATH = "../"

nlp = spacy.load(MODEL_PATH)
# nlp = spacy.load(m_dir)


def predict(text):
    entities = {}
    translator = str.maketrans(string.punctuation, ' ' * len(string.punctuation))
    text = text.translate(translator)
    doc = nlp(text)
    # print(
    #     "SPACY"
    # )
    # print(doc)
    for ent in doc.ents:
        entities[ent.label_] = {'text': ent.text, 'start': ent.start_char}
    return entities

# data_dir = "../../model/ner_model"
# Out:
#   File "C:\Users\Uridah\AppData\Local\Temp/ipykernel_11208/1123235015.py", line 11
#     MODEL_PATH =
#                  ^
# SyntaxError: invalid syntax
